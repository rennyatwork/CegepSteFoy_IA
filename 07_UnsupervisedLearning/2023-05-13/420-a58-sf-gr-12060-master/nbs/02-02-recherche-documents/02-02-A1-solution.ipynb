# %% [markdown]
# **420-A58-SF - Algorithmes d'apprentissage non supervisé - Hiver 2023 - Spécialisation technique en Intelligence Artificielle**<br/>
# MIT License - Copyright (c) 2023 Mikaël Swawola
# <br/>
# ![Travaux Pratiques - Recherche de documents](static/02-02-A1-banner.png)
# <br/>
# **Objectif: Lors de l'exploration d'un jeu de données constitué de documents textes - tels que des pages Wikipedia, des articles de presse, StackOverflow, etc., il est courant de chercher à trouver quels sont les documents similaires. L'objectif de cet exercice est de mettre en oeuvre les techniques de recherche adaptées (ici les plus proches voisins) à ce type de données. Les documents utilisés sont les pages Wikipedia de personnalités.**

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

# Le reste des modules sera importé au fur et à mesure des exercices ...

# %% [markdown]
# L'archive `people.zip` contient 4 fichiers:
#
# * **people_wiki.csv**: jeu de données consituté des pages Wikipedia de personnalités
# * **people_wiki_map_index_to_word.json**: mapping entre les mots et les indices
# * **people_wiki_word_count.npz**: vecteurs d'occurence des mots (word count / sacs de mot) pour chaque document
# * **people_wiki_tf_idf.npz**: vecteurs TF-IDF pour chaque document
#
# Dans l'énoncé de ce TP, les mots "article" et "document" sont interchangeables.

# %% [markdown]
# ## 1 - Chargement du jeu de données

# %% [markdown]
# **Exercice 1-1 - À l'aide de la librairie Pandas, lire le fichier de données `people/people_wiki.csv`. Afin de permettre les opérations de type `join` effectuées plus loin dans le TP, nommez l'index de la trame de donnée `id`**

# %%
# Compléter cette cellule ~ 2 lignes de code

# %%
wiki = pd.read_csv('../../data/people/people_wiki.csv')
wiki.index.name = 'id'

# %% [markdown]
# **Exercice 1-2 - Afficher les 5 premières lignes de la trame de données. Quelles informations contiennent les colonnes ?**

# %%
# Compléter cette cellule ~ 1 ligne de code

# %%
wiki.head()
# Out:
#                                                   URI                 name  \
# id
# 0         <http://dbpedia.org/resource/Digby_Morrell>        Digby Morrell
# 1        <http://dbpedia.org/resource/Alfred_J._Lewy>       Alfred J. Lewy
# 2         <http://dbpedia.org/resource/Harpdog_Brown>        Harpdog Brown
# 3   <http://dbpedia.org/resource/Franz_Rottensteiner>  Franz Rottensteiner
# 4                <http://dbpedia.org/resource/G-Enka>               G-Enka
#
#                                                  text
# id
# 0   digby morrell born 10 october 1979 is a former...
# 1   alfred j lewy aka sandy lewy graduated from un...
# 2   harpdog brown is a singer and harmonica player...
# 3   franz rottensteiner born in waidmannsfeld lowe...
# 4   henry krvits born 30 december 1974 in tallinn ...

# %% [markdown]
# ## 2 - Extraction du nombre de mots

# %% [markdown]
# Les vecteurs d'occurence des mots (**word count**) du jeu de données ont été préalablement extrait dans le fichier `people/people_wiki_word_count.npz`. Ces vecteurs sont regroupés dans une matrice diluée (sparse), où la i-ème ligne donne le vecteur d'occurence des mots pour le i-ème document. Chaque colonne correspond à un mot unique apparaissant dans le jeu de données. Le mapping entre les mots et les indices est donné dans `people/people_wiki_map_index_to_word.json`
#
# La fonction suivante permet le chargement des vecteurs d'occurence des mots:

# %%
from scipy.sparse import csr_matrix

def load_sparse_csr(filename):
    loader = np.load(filename)
    data = loader['data']
    indices = loader['indices']
    indptr = loader['indptr']
    shape = loader['shape']
    
    return csr_matrix( (data, indices, indptr), shape)

# %% [markdown]
# La fonction ci-dessus utilise `csr_matrix` de la bibliothèque SciPy:<br/>
# [class scipy.sparse.csr_matrix(arg1, shape=None, dtype=None, copy=False)](https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.csr_matrix.html)

# %% [markdown]
# **Exercice 2-1 - À l'aide de la fonction ci-dessus, charger le ficher contenant les vecteurs d'occurence des mots**

# %%
# Compléter cette cellule ~ 1 ligne de code

# %%
from scipy.sparse import csr_matrix

word_count = load_sparse_csr('../../data/people/people_wiki_word_count.npz')

# %% [markdown]
# **Exercice 2-2 - En vous référant à la documentation de la fonction `csr_matrix`, convertissez la matrice `word_count` en tableau NumPy. Que constatez-vous ?**

# %%
# Compléter cette cellule ~ 1 ligne de code
word_count
59071*547979*8
# Out:
# 258957340072

# %%
word_count.toarray()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 word_count.toarray()
#
# File /usr/local/lib/python3.11/site-packages/scipy/sparse/_compressed.py:1051, in _cs_matrix.toarray(self, order, out)
#    1049 if out is None and order is None:
#    1050     order = self._swap('cf')[0]
# -> 1051 out = self._process_toarray_args(order, out)
#    1052 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1053     raise ValueError('Output array must be C or F contiguous')
#
# File /usr/local/lib/python3.11/site-packages/scipy/sparse/_base.py:1298, in spmatrix._process_toarray_args(self, order, out)
#    1296     return out
#    1297 else:
# -> 1298     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 241. GiB for an array with shape (59071, 547979) and data type int64

# %% [markdown]
# **Exercice 2-3 - À l'aide du module json ou de la librairie Pandas, charger le ficher contenant le mapping entre les mots et les indices. Combien y a-t-il de mots dans le dictionnaire ?**

# %%
# Compléter cette cellule ~ 2-3 lignes de code

# %%
import json

with open('../../data/people/people_wiki_map_index_to_word.json') as f:
     map_index_to_word = json.load(f)
len(map_index_to_word)
# Out:
# 547979

# %%
map_index_to_word
# Out:
# {'biennials': 522004,
#  'lb915': 116290,
#  'shatzky': 127647,
#  'woode': 174106,
#  'damfunk': 133206,
#  'nualart': 153444,
#  'hatefillot': 164111,
#  'missionborn': 261765,
#  'yeardescribed': 161075,
#  'theoryhe': 521685,
#  'vinalop': 222759,
#  'soestdijk': 166345,
#  'boncea': 150371,
#  'spiders': 519990,
#  'bienniale': 429277,
#  'woody': 541515,
#  'trawling': 189895,
#  'pampoulovawagner': 201040,
#  'bentara': 202586,
#  'laserbased': 25758,
#  'caner': 346073,
#  'canes': 478262,
#  'canet': 436468,
#  'iaspark': 395341,
#  'categoriesborn': 12586,
#  '5982': 277649,
#  'caney': 459867,
#  'phosphorushe': 379479,
#  'yusaf': 270311,
#  'hhsoffice': 141697,
#  '5985': 32985,
#  'fsos': 109474,
#  'caned': 324502,
#  'gaa': 534680,
#  'iguau': 456103,
#  'storiesin': 513151,
#  'braziljorge': 107111,
#  'iguaz': 127410,
#  'kealhofer': 342134,
#  'canek': 159182,
#  '2116': 429919,
#  'canem': 83461,
#  'victorialooking': 58169,
#  'martre': 111954,
#  'lippert': 491344,
#  'pagesolove': 33220,
#  'sowell': 489254,
#  'weiskopfs': 344360,
#  'hedquist': 165506,
#  'andersanders': 395286,
#  'raouf': 429695,
#  'steppaillen': 107270,
#  'fjate': 223085,
#  'heroesin': 467576,
#  'executivemanager': 66489,
#  'papanastassiouwasserburgs': 159142,
#  'superpowered': 459105,
#  'voiceactress': 171818,
#  'fullblooded': 481011,
#  'genocidekamuhanda': 153083,
#  'radkes': 273097,
#  'composertippett': 435288,
#  'grueling': 521723,
#  'season1bouyer': 303715,
#  'wooden': 539936,
#  'comicborn': 98129,
#  'virtuosos': 502172,
#  'raoul': 533170,
#  'illinoisrockefellersilvia': 125605,
#  'nielsenfunk': 139592,
#  'woodes': 31701,
#  '598m': 118443,
#  'semiautomatic': 514410,
#  'immunities': 453709,
#  'racedue': 43704,
#  'jher': 414423,
#  'oropolitics': 369894,
#  'thrace': 26128,
#  'voiceguitar': 3162,
#  'jhey': 103639,
#  'snuggles': 4139,
#  'brockiehe': 149987,
#  'frederick': 543425,
#  'pinerichland': 292867,
#  'deadheads': 121406,
#  'troycale': 351786,
#  'kqrsminneapolis': 152278,
#  'vlez': 517536,
#  'collegerozanskis': 192387,
#  'consenting': 479773,
#  'finalsst': 11048,
#  'bastenesque': 310891,
#  'irelandroche': 217427,
#  'career1996': 215694,
#  'leopardis': 155769,
#  '2013previously': 460148,
#  'antisandinista': 184027,
#  'outfieldera': 144388,
#  'comically': 513628,
#  '2005marino': 349655,
#  'yanhai': 141251,
#  'termbarro': 274617,
#  'outfielders': 526971,
#  'replaced': 546924,
#  'isbin': 459302,
#  'paparizu': 44185,
#  'reber': 456999,
#  'rocqui': 207708,
#  'alwan': 491122,
#  'bhubaneshwar': 399845,
#  'syndromehe': 460242,
#  'dogscott': 155848,
#  'slubena': 385730,
#  'iraq20042005': 178147,
#  'ninefight': 42708,
#  'softwareas': 354920,
#  'canadaday': 51281,
#  'instituteoue': 198370,
#  'ulpio': 54184,
#  'whbqam': 118422,
#  'shvegerins': 213251,
#  '2008hilary': 122189,
#  'jlana': 124099,
#  'votesprior': 459253,
#  'geoghegans': 438741,
#  'gaspatilla': 324178,
#  'deferring': 124557,
#  'gayathri': 298893,
#  'reidun': 452986,
#  'soundsdrew': 423,
#  'crowdpleasing': 292122,
#  '2003radloff': 320227,
#  'tokmok': 287716,
#  'vr51': 372568,
#  'talba': 179396,
#  'raavan': 464594,
#  'gastein': 134708,
#  'nok10': 204313,
#  'adultsas': 237067,
#  'buades': 36108,
#  'candmag': 507616,
#  'gasteig': 392086,
#  'legislaturebarraga': 311807,
#  'realbeanz': 179459,
#  'aviezer': 310902,
#  'lohren': 160168,
#  'frs': 539084,
#  'gasteiz': 303871,
#  'chanthaburi': 103456,
#  'gurinders': 182056,
#  'hiranuma': 371831,
#  'urbanbaby': 7246,
#  'modurn': 108979,
#  'elfvin': 210428,
#  'dnd': 399750,
#  'dng': 505359,
#  'dnf': 513629,
#  'dna': 542302,
#  'englandlifsons': 157092,
#  'dnc': 523024,
#  'dnb': 492771,
#  'dnl': 361850,
#  'dno': 415431,
#  'luchin': 11422,
#  'dni': 498236,
#  'dnk': 280927,
#  'inevitable': 529809,
#  'dnu': 16077,
#  'dnt': 150160,
#  'gothicmade': 153547,
#  'dnp': 464065,
#  '320506': 60694,
#  '124pm': 259004,
#  'kdziora': 220094,
#  'attenboroughin': 258997,
#  'attenboroughii': 389450,
#  'blasss': 190086,
#  'benedikt': 473505,
#  'linzbobby': 326871,
#  'sonhawick': 118345,
#  'ancastedundasflamboroughwestdale': 318333,
#  'borstal': 494481,
#  'populations': 538271,
#  'chapterinvited': 57924,
#  'borstad': 7914,
#  'gijs': 492503,
#  'gijn': 511449,
#  'rickman': 509770,
#  'ternuraincluding': 109605,
#  'milestones': 528741,
#  'expeditionary': 530154,
#  'securitylink': 70741,
#  'factiondue': 249593,
#  'oldwhite': 164293,
#  'ongirl': 379218,
#  'editornews': 34820,
#  'yearstandly': 374138,
#  '18o': 152283,
#  'wbzfm': 177754,
#  'uhlenbeek': 384379,
#  'planprescribercom': 211944,
#  'missionizing': 358226,
#  'dn5': 302164,
#  'cachaahe': 167832,
#  'godsandmonstersnet': 78576,
#  'chacottmckie': 92103,
#  'niven': 478423,
#  'ozment': 387785,
#  'dangdut': 418883,
#  'betdaq': 231888,
#  'journalsdruviete': 336649,
#  'tnnessons': 372688,
#  'legalva': 267175,
#  'irrationalist': 432385,
#  'usiuprior': 156395,
#  'mainevented': 432746,
#  'postbeginning': 60574,
#  'peopleher': 23167,
#  'langenbroich': 273971,
#  'goleas': 3474,
#  'sashays': 179094,
#  'dagriculture': 14323,
#  'breedens': 230886,
#  'insectarium': 393241,
#  'masekelain': 313160,
#  'castelo': 94551,
#  'azurite': 84044,
#  'basolo': 383335,
#  '200mile': 434259,
#  'norplast': 276091,
#  'latifaafter': 5136,
#  'olympiadhe': 87552,
#  'delmark': 483847,
#  'andreessenhorowitz': 234408,
#  'kraig': 440505,
#  'rosmonda': 437842,
#  'brandon': 541598,
#  'kfrc': 485824,
#  'shirked': 155003,
#  'fetters': 481077,
#  'thechancerie': 343871,
#  'tenalirama': 256962,
#  'krais': 324217,
#  '1974dyson': 36470,
#  'golddixon': 238869,
#  'ndvornk': 349158,
#  'menem': 519165,
#  'tohnay': 191692,
#  'venuesin': 498042,
#  'fieldsince': 390567,
#  'greylox': 271681,
#  'immigrantschneeberger': 309741,
#  'tevanyan': 19532,
#  'penhalonga': 17845,
#  'goober': 477968,
#  'balado': 391698,
#  'partymohamud': 374173,
#  'leavingafter': 98656,
#  'barbro': 463557,
#  'flossin': 342526,
#  'rolster': 311143,
#  '2002andre': 322961,
#  'leaguesnicknamed': 295418,
#  'morsesmale': 167928,
#  'dauvergne': 465435,
#  'ombattu': 259596,
#  'varyingly': 358419,
#  'worksdadyans': 84960,
#  'arkarazo': 124120,
#  'actingmann': 284127,
#  'dungkar': 20352,
#  'fazul': 386343,
#  'macken': 477363,
#  'chandos': 528336,
#  'shreya': 465102,
#  'injurymckeever': 66655,
#  'dikinis': 99674,
#  'marquett': 283498,
#  'ontaylor': 101785,
#  'sheenboro': 197283,
#  'chandon': 477855,
#  'analysisstill': 203812,
#  'sankarabharanam': 101690,
#  'disengaging': 335207,
#  'lafource': 199564,
#  'welcomed': 539363,
#  'malba': 425920,
#  'stoicism': 455423,
#  'ovalat': 24281,
#  'tillamook': 320600,
#  'tarbuckhodgson': 137902,
#  'telsys': 273308,
#  'seasoncurrie': 170537,
#  'bhatkal': 212029,
#  'claflin': 174070,
#  'ferrante': 503492,
#  'activating': 462046,
#  'telemetryshe': 83453,
#  'michelidakidarmouslis': 114175,
#  'welcomes': 497898,
#  'unimodality': 209880,
#  'entendstu': 209614,
#  'haripal': 364370,
#  'fiq': 216094,
#  'donemusin': 235759,
#  'fit': 542897,
#  'reviewingas': 48381,
#  'womenolson': 363469,
#  'fix': 535542,
#  'nationallyaccredited': 40567,
#  'folate': 415189,
#  'fic': 127131,
#  '204for815': 65998,
#  'postharvest': 394097,
#  'fif': 101309,
#  'fig': 515638,
#  'fid': 468759,
#  'fie': 478402,
#  'ergonomidesign': 71556,
#  'fih': 482219,
#  'fii': 134779,
#  'athleticcanvey': 285449,
#  'fio': 453059,
#  'fil': 537518,
#  'shively': 402001,
#  'mirandas': 469490,
#  'shivay': 161466,
#  'beilharz': 398501,
#  'foolin': 158507,
#  'cimms': 441713,
#  'packardin': 111548,
#  'sovs': 303334,
#  'vallibel': 359756,
#  '1984buffalo': 52999,
#  'hisin': 377426,
#  'mbarker': 373248,
#  'goresbrook': 110776,
#  'challengethe': 19032,
#  'ankor': 340561,
#  'ctamong': 68352,
#  'allergen': 393736,
#  'matamoras': 203483,
#  'hospitalier': 16297,
#  'conner': 532862,
#  'scaglione': 118922,
#  '26568': 85500,
#  'superdad': 379291,
#  'persita': 359286,
#  'musang': 280147,
#  'picturesfujimura': 127627,
#  'sugarplums': 344760,
#  'frewer': 300083,
#  'proffitts': 322661,
#  'grfenroda': 306879,
#  'musans': 268208,
#  'goverors': 13680,
#  'mancordycollins': 333985,
#  'lightningcloud': 360360,
#  'kowt': 230770,
#  'zuid': 464363,
#  '1395336': 249251,
#  'victoriangeorgianinspired': 336811,
#  'pavlina': 405971,
#  'environmentallyaware': 286532,
#  'titlefrom': 453772,
#  'parasiten': 283516,
#  'goldfishbraun': 345342,
#  'tenin': 487209,
#  'counterstreaming': 109742,
#  'holisticallyhistorical': 366008,
#  'niederst': 422575,
#  'buttercups': 183230,
#  'programmesmith': 252942,
#  'ideograph': 114893,
#  'exmanchester': 408299,
#  'malczewska': 347174,
#  'lapua': 425250,
#  'syd': 531185,
#  'dailyon': 114648,
#  'hivaidsawareness': 78876,
#  '2007jennings': 191868,
#  'economistherminio': 29848,
#  '7in': 504082,
#  'resolvedthis': 275819,
#  'cuchera': 244040,
#  'sportbikefor': 246916,
#  'mansonat': 122183,
#  'cinematographyin': 309326,
#  'pusks': 474954,
#  'abbots': 438904,
#  'worldbasem': 209262,
#  'hirschmore': 354975,
#  'julide': 305262,
#  'malich': 427967,
#  'ooooooone': 369795,
#  'pinakothek': 354639,
#  'bonelli': 460060,
#  'eventsakbar': 4528,
#  'pumpkins': 528279,
#  'springerkaufman': 111265,
#  'bonello': 448194,
#  '19731982in': 160307,
#  'bonella': 82461,
#  'nieuwpoort': 454564,
#  'berwick': 526842,
#  'abbotm': 246937,
#  'pakmed': 28471,
#  'sikiru': 18680,
#  'danuartadanuartas': 319007,
#  'serviceexternal': 66364,
#  '2015a': 447829,
#  'parkson': 187243,
#  'pisinski': 28517,
#  '28baron': 233604,
#  'tourcoetzee': 111546,
#  'stranka': 422748,
#  'msu': 522640,
#  'vilarinhos': 326440,
#  'albumrolinha': 372678,
#  'kiersey': 46609,
#  'jkhis': 134574,
#  'krieble': 346681,
#  'shivajis': 89941,
#  'portmanteau': 507813,
#  'ineffectively': 444965,
#  'palani': 463350,
#  'alderson': 515665,
#  'competitionaaltonen': 77706,
#  'kneeduring': 381811,
#  'cofounderceo': 25755,
#  'whipsaltzman': 170263,
#  'curiouser': 221375,
#  'stoneham': 477185,
#  'skanderbeg': 231304,
#  'freimanescreen': 368646,
#  'liberecagusts': 128925,
#  'hushang': 47274,
#  'jeanphi': 352311,
#  'modernitys': 405970,
#  'tumes': 417354,
#  'analysiscurrently': 354767,
#  'niederers': 302297,
#  '2014mimis': 315738,
#  'ritterband': 236950,
#  'publishingms': 371346,
#  'sarodya': 128698,
#  'malick': 521020,
#  'aigles': 472231,
#  'cogeneral': 468768,
#  '13bn': 51149,
#  'couevas': 98663,
#  'habilitandenstipendiat': 360934,
#  'capsat': 406524,
#  'lewica': 445059,
#  'mercurys': 491067,
#  'swaralayam': 369721,
#  'systemsedwards': 381756,
#  'gmpls': 249466,
#  'shoutcasting': 323965,
#  'weighingroomriding': 334713,
#  'toomey': 491205,
#  'abdulwahab': 421143,
#  'izchak': 340747,
#  'casandra': 488608,
#  'bicskeis': 69880,
#  'huewen': 285078,
#  'frderpreis': 460028,
#  'onceinalifetime': 473412,
#  'songcycles': 456047,
#  '386840': 116559,
#  'yearsdrgillani': 296736,
#  'winterville': 411392,
#  'aztecadel': 185048,
#  'agurida': 122043,
#  'olthwaite': 137701,
#  'juaristi': 327900,
#  'tulsahis': 5499,
#  'talkinhe': 36361,
#  '272': 530207,
#  'nonastrological': 303009,
#  'ahmet': 527576,
#  'exclaimed': 498820,
#  '5606': 165413,
#  'mozartgemeinde': 22424,
#  'escopetarras': 117254,
#  'freelicks': 276235,
#  '274': 529544,
#  '2007lai': 319979,
#  'english2': 115277,
#  'provincecashin': 312614,
#  'hederson': 359424,
#  'wageswanson': 53952,
#  'sadki': 177396,
#  'germanymende': 316388,
#  'redesigned': 526793,
#  '15703': 235555,
#  'eslami': 459386,
#  '15706': 382839,
#  '1994tunisia': 337488,
#  'mandatrio': 266860,
#  'sciencesstaffan': 350595,
#  'carlands': 410407,
#  'lilinho': 64352,
#  'merseys': 365509,
#  'vectorborne': 448086,
#  'harassmenthis': 186529,
#  '24144': 113860,
#  'betteshanger': 305890,
#  'cotecnas': 138755,
#  'kraftlag': 403274,
#  'asnmsu': 177534,
#  'targa': 512651,
#  'instructionformer': 139085,
#  'trendsas': 282356,
#  'auctionsin': 272568,
#  'legislaturebeginning': 182087,
#  'welshofers': 252529,
#  'germanyk1997the': 266260,
#  'recordsoriginally': 374686,
#  'zidanegourcuff': 216949,
#  'netzbandt': 307490,
#  'footthe': 228790,
#  'jhen': 322933,
#  'kuhnian': 432997,
#  'terrorsleavitts': 75637,
#  'crocs': 482760,
#  'pixilated': 406476,
#  'karsavina': 108360,
#  'everscottas': 57582,
#  'democracyrecently': 22785,
#  'existentialistsin': 32553,
#  'eurobasketcom': 412149,
#  'descosidos': 209224,
#  'monger': 441664,
#  'functionary': 489924,
#  '1997bolen': 68773,
#  'modelsplatt': 137166,
#  'rocketplane': 387360,
#  '2012firth': 382267,
#  'maji': 306406,
#  'majk': 248523,
#  'majd': 317462,
#  'colloids': 472393,
#  'maja': 517442,
#  'azertion': 245409,
#  'nettle': 470313,
#  'insandamat': 301561,
#  'federley': 377241,
#  'demierre': 260780,
#  'awardkays': 126773,
#  'clichy': 482883,
#  'hiberian': 236623,
#  'costello': 536020,
#  'morawetz': 390996,
#  '2012daniels': 186114,
#  'tathamlaird': 147380,
#  'dickey': 525158,
#  'katsastus': 229468,
#  'rajapaksachampika': 289765,
#  'dicker': 472293,
#  'gillham': 246509,
#  'khalwale': 53238,
#  'mkhasmchog': 98728,
#  'gebrselassieworku': 73912,
#  'otello': 530252,
#  'hangama': 432368,
#  'redland': 485209,
#  'belgiumaprmay': 159585,
#  'chelios': 467322,
#  'conpany': 412067,
#  'apace': 402152,
#  'topfour': 462751,
#  'mikheil': 513118,
#  'economicallydriven': 212859,
#  'koloffchad': 204266,
#  'fellowpounds': 28053,
#  'lepidoptery': 140303,
#  '20052011was': 356166,
#  'apact': 125429,
#  'kaiapoi': 50813,
#  'attacksthroughout': 292251,
#  'arrogant': 524724,
#  'xlvii': 508619,
#  'bruneian': 466533,
#  'khvsgl': 12705,
#  'christiansbill': 184352,
#  '2005machage': 22862,
#  'damagede': 351582,
#  'bruneteaus': 6058,
#  '2014morris': 318716,
#  'neufbrisach': 175693,
#  'meeshelle': 78884,
#  'heartsounds': 97322,
#  'festivalfor': 428075,
#  'dumontier': 193672,
#  'satalyte': 173087,
#  'beginningdeva': 234376,
#  'theodosios': 24659,
#  'eurogp': 242552,
#  'panicsville': 141257,
#  'intorno': 445047,
#  'fruita': 440077,
#  'shakhovskayain': 267457,
#  'worldwideyaitanes': 267618,
#  'optimise': 396751,
#  'ennedi': 350087,
#  'nomenclaturedickinson': 369048,
#  'researchdescribed': 57022,
#  'scotlandfraser': 59602,
#  '2011s': 527026,
#  'alkudmani': 437419,
#  'veenlijken': 167576,
#  'effectsmusician': 121939,
#  'mxtv': 378539,
#  'amply': 451152,
#  'viehweg': 416215,
#  'aadam': 204323,
#  'primorac': 475690,
#  'muddled': 459408,
#  'nonmatchdays': 220022,
#  'programmatic': 513634,
#  'courneuve': 392914,
#  'manasseris': 262920,
#  'conanp': 200389,
#  'ludacristhe': 117251,
#  'garamendi': 463080,
#  'braconi': 141110,
#  'zahlen': 238511,
#  'staytongirod': 41534,
#  'mexicoin': 524820,
#  'tyndale': 516888,
#  'smpte': 492004,
#  'tyndall': 512807,
#  'proibidos': 226337,
#  'locallyderived': 354736,
#  'improvisatorysounding': 164487,
#  'doran': 524674,
#  'jorgovanka': 415,
#  '19771980': 526776,
#  'japankrentzman': 365948,
#  'ruusunen': 134926,
#  'schofieldhe': 247313,
#  'studiesgura': 215209,
#  'gizzyvan': 299811,
#  'gaventas': 151258,
#  'markpartnering': 241045,
#  'conductive': 468181,
#  'subarray': 267018,
#  'therekenneth': 322360,
#  'breakawayvasseur': 223947,
#  'shaider': 256046,
#  'spectrometers': 435047,
#  '19671dr': 383655,
#  'keyboardstony': 325146,
#  'sletten': 411782,
#  'gwozdz': 230221,
#  'seriously1': 39020,
#  '2002there': 284422,
#  'lapping': 400054,
#  'bealein': 81242,
#  'bpool': 87006,
#  'gced': 372510,
#  'meridional': 390078,
#  'learin': 408767,
#  'kazenga': 107002,
#  'cduk': 457884,
#  'copythe': 63436,
#  '29th': 540830,
#  'gcel': 248667,
#  'understandsfollowing': 69776,
#  'mailart': 238227,
#  '18921992': 203862,
#  'enochenochs': 191864,
#  'mexiconegrete': 65334,
#  'repremiered': 46951,
#  'khandap': 151246,
#  'sanguinetis': 110521,
#  'corvair': 46772,
#  'sucarnochee': 177119,
#  '2013fascinated': 23390,
#  'directorcohen': 134479,
#  'fundmcneilly': 198064,
#  'pitcheramaral': 6129,
#  '2011commander': 266951,
#  'officialhis': 68463,
#  'specialsit': 22198,
#  'coloursshe': 427126,
#  'fizzingly': 320772,
#  'bloggers': 534570,
#  'borrussia': 156058,
#  'meaningfulness': 45081,
#  'salvagedused': 299258,
#  'lankain': 91379,
#  'gretaborn': 207425,
#  'issuesblack': 130158,
#  'ahomage': 118958,
#  'praticado': 231099,
#  'eldoradowhile': 249869,
#  'bakalyans': 185281,
#  'washingtonlaughlin': 108479,
#  'gstaadkarl': 353797,
#  'otolaryngologists': 177582,
#  'escalada': 195228,
#  'castebased': 485678,
#  'chuanyun': 383788,
#  'growthessays': 269265,
#  'lanett': 423721,
#  'hardthrowers': 327753,
#  'cartright': 66358,
#  'imperfecta': 462705,
#  'gnima': 213078,
#  'finsbury': 485668,
#  'hegarty': 495078,
#  'nearupset': 286604,
#  'leduey': 335648,
#  'twangafter': 96800,
#  'berserky': 245712,
#  'giessen': 511845,
#  'takingchong': 307154,
#  '1679': 392644,
#  'picturejournalist': 234329,
#  'kidp': 274055,
#  'turda': 175792,
#  'mangual': 252173,
#  'artmahurin': 19982,
#  'miamiheadquartered': 318075,
#  'kgarm': 55571,
#  'nolanirish': 283376,
#  'koutsopoulos': 188232,
#  'arkiv': 355857,
#  'experienceboyces': 129466,
#  'state197579': 227692,
#  'kids': 545637,
#  'jarrin': 252685,
#  'aberchirder': 21014,
#  'developmentoriented': 18899,
#  'angee': 323580,
#  'propellants': 207925,
#  'uplifting': 524317,
#  'szetsung': 130410,
#  'teacherher': 222892,
#  '2004contrary': 351311,
#  'lafferentz': 44264,
#  'australiamark': 177589,
#  'mazher': 256697,
#  'sreten': 435027,
#  'herreros': 260628,
#  'thoughthis': 11490,
#  'alkhabyyr': 64944,
#  '1672': 2787,
#  'jointservice': 399562,
#  'pp6176': 229696,
#  'lithuaniahe': 57815,
#  'whatsherface': 22570,
#  'systemdaniel': 222968,
#  'aollynch': 78278,
#  'englandbelgium': 174458,
#  'unor': 93181,
#  'volapkspeakers': 331332,
#  'stanzaks': 362146,
#  'canoeing': 527324,
#  '254': 531510,
#  'tedxtokyo': 114667,
#  'walshby': 66352,
#  'anger': 538333,
#  'unob': 222989,
#  '1990playboy': 145665,
#  'hashilarosa': 248315,
#  'porvorimbbc': 126385,
#  'unog': 416100,
#  'recordsjack': 398023,
#  'branchhedgpeth': 298097,
#  'controversy': 546065,
#  'unol': 327774,
#  'kayama': 56269,
#  'roehrkasse': 397847,
#  'bricklayer': 509048,
#  'powsin': 191323,
#  'grinfield': 166932,
#  'planetable': 372397,
#  'remand': 511437,
#  'spews': 148186,
#  'producermalavasi': 102010,
#  'valdisre': 441889,
#  'statefrom': 461521,
#  'castlewellan': 294092,
#  'seasonpauls': 246434,
#  'baudry': 271575,
#  'campact': 4453,
#  'tasvir': 71716,
#  'georgics': 84840,
#  'teuschl': 190432,
#  'edelstammolin': 309844,
#  'sevenandahalf': 461689,
#  'staphylococci': 372830,
#  'georgica': 7027,
#  'zeor': 89872,
#  'altar': 527275,
#  'soundsation': 161371,
#  '75in': 197451,
#  'peremptory': 393706,
#  'menwan': 268290,
#  'futari': 387245,
#  'statesjen': 72493,
#  'stillness': 516400,
#  'mentorm': 319607,
#  'rajastanafter': 10507,
#  'veteran': 545906,
#  'aldhousegreens': 109743,
#  'toshizumi': 364310,
#  'yorklisted': 198299,
#  'absurdities': 461919,
#  '2010marlton': 155149,
#  'programinvited': 7568,
#  'karogshe': 153999,
#  'hechos': 409796,
#  'solesides': 154660,
#  'historicalfiction': 216151,
#  'hrfest': 234338,
#  'preparando': 235799,
#  'topography': 515769,
#  'valleys': 530848,
#  'monika': 526253,
#  'saatchi2007': 15615,
#  'kommunal': 409229,
#  'andryczuk': 342562,
#  'gainsbourg': 508291,
#  'vivalma': 202649,
#  'marignane': 306361,
#  'hastons': 339927,
#  'conferenceshe': 493801,
#  'pastchairman': 405494,
#  'radzinsky': 299298,
#  'bravewell': 162064,
#  'projectsengel': 186638,
#  'godlin': 357773,
#  '1958ehrenberg': 322841,
#  'stutzmann': 138193,
#  'bemsha': 259129,
#  'cristianes': 19489,
#  'godlia': 43799,
#  'cupriley': 252936,
#  'brays': 33599,
#  'identityhis': 114934,
#  'senecal': 64296,
#  'rescaled': 203490,
#  'dokka': 449636,
#  'yukawa': 196354,
#  'ascapjaqueline': 358055,
#  'redbrook': 95717,
#  'brebants': 167762,
#  'jerusalemgreenberg': 335245,
#  'gligori': 419258,
#  '47collingwood': 331791,
#  'championsthus': 5741,
#  'drummeras': 412772,
#  'indicative': 514223,
#  'dokku': 152698,
#  'clevedon': 519535,
#  'saucelilker': 383817,
#  'nonconsecutive': 520063,
#  'sleuthing': 452893,
#  'cambridgelord': 398550,
#  'bambos': 435283,
#  'victoria': 546580,
#  'scholasticas': 478305,
#  'languagenayler': 156392,
#  'kremlins': 454565,
#  '2002gerlachs': 186498,
#  'francedeveloped': 225697,
#  'furtsch': 120528,
#  'potterof': 257552,
#  'anklehinton': 212758,
#  'lakembafurolo': 337060,
#  'daniellespiva': 96601,
#  '2004gronkiewiczwaltz': 156344,
#  'mccumbee': 200097,
#  'svechi': 393117,
#  'unsinkable': 470150,
#  'rusherfollowing': 359398,
#  'yavana': 383534,
#  'staff2013': 172757,
#  '2014ole': 136066,
#  'argylein': 433937,
#  'dailyhe': 403778,
#  'ecoterrorismhardwick': 183086,
#  'visitin': 416140,
#  'pileggi': 48054,
#  'sneha': 456161,
#  'hoysince': 136989,
#  'gambale': 488575,
#  'onemake': 496328,
#  'naurai': 303675,
#  'ratatattat': 19625,
#  'fruh': 31321,
#  'oneschulmans': 195445,
#  'fruc': 225390,
#  'gamblingaddicted': 132854,
#  'layeredsound': 277595,
#  'youtubeshahrzad': 167261,
#  'fehman': 279418,
#  'dne': 214844,
#  'iheanacho': 192828,
#  'itsuwa': 371689,
#  'giannabest': 24938,
#  'httpwwwhavchrengcroatianfilmcroatianfilmcataloguenosleepwontkillyou': 156463,
#  'agassi': 517708,
#  'schrder': 517781,
#  'taifai': 406291,
#  'spectatorhe': 240082,
#  'herrin': 488502,
#  'evacuees': 452390,
#  '1961wirsum': 218786,
#  'holofernes': 163500,
#  'hammersberg': 41108,
#  'vrilissia': 327102,
#  'qaralov': 106072,
#  'herria': 392151,
#  'fiveway': 493441,
#  'myfontscommarshs': 107219,
#  'fingleson': 406684,
#  'spaceships': 478562,
#  'svipdagr': 102809,
#  '2011books': 163539,
#  'altai': 444944,
#  'imtogether': 243941,
#  'biocharacterization': 258947,
#  'everestjbf': 225369,
#  'categoryluckey': 381595,
#  'wankelengined': 265777,
#  'parliamentfor': 450595,
#  'vonage': 221910,
#  'eisnehower': 17908,
#  'honeymood': 122135,
#  'hurdlesand': 364213,
#  'associationaside': 332116,
#  'functiongrier': 358766,
#  'macedoniahis': 138786,
#  'knockdownin': 378855,
#  'marshall': 544997,
#  'honeymoon': 527844,
#  'lebedlebedbizstafflebed': 187367,
#  'semifinalon': 393152,
#  'duccia': 428436,
#  'oppressionhe': 144773,
#  'cruisewagner': 422290,
#  'marshals': 525554,
#  'penaltiesdixie': 129988,
#  'haboush': 282330,
#  'university3': 340779,
#  'university2': 398401,
#  'university1': 497585,
#  'university6': 70917,
#  'university5': 192796,
#  'fluegelman': 217371,
#  'abdulhamid': 58421,
#  'biddulph': 454458,
#  'littenstall': 108375,
#  'islamin': 493567,
#  'timewitt': 335540,
#  'courtprofessor': 20641,
#  'chairmanadubato': 55125,
#  'dnv': 444313,
#  'digitalvibe': 110375,
#  'historianshuntsman': 49679,
#  'allsoutheastern': 511044,
#  'alexandrian': 443364,
#  'belfaston': 281004,
#  'secretarykeith': 94479,
#  'dns': 506262,
#  'altan': 457766,
#  'awardswoodard': 374357,
#  'universityb': 315716,
#  'universitya': 527175,
#  'masterkris': 275982,
#  'tobagomaraj': 313450,
#  'thesaurus': 487872,
#  'alistairs': 3994,
#  'germanirish': 448014,
#  'olowo': 31779,
#  'kaizers': 460749,
#  'moraima': 307640,
#  'universitys': 546532,
#  'vietnamese': 539756,
#  'endocytic': 209899,
#  'mgab': 207712,
#  'huoche': 369302,
#  'dny': 465205,
#  'layin': 140064,
#  'leaguegul': 11924,
#  'agrifood': 506525,
#  'aphasia': 490245,
#  '2231': 207291,
#  'fheasgair': 199122,
#  'mzilikazi': 395283,
#  'lesea': 363629,
#  '2233': 120379,
#  'gelbers': 352136,
#  'allbaughs': 114959,
#  'sondelli': 346013,
#  ...}

# %%
word_count[:,519990].toarray().sum()
# Out:
# 32

# %% [markdown]
# **Exercice 2-4 (optionnel) - Extraire par vous-même les vecteurs d'occurence des mots. Un bon point de départ est la fonction `sklearn.CountVectorizer`**

# %%
# Compléter cette cellule

# %% [markdown]
# ## 3 - Recherche des plus proches voisins avec représentation word count

# %% [markdown]
# Commençons par trouver les voisins les plus proches de la page Wikipedia de **Barack Obama**. Les vecteurs d'occurence des mots (**word count**) seront utilisés pour représenter les articles et la **distance euclidienne** pour mesurer la similarité.

# %% [markdown]
# [class sklearn.neighbors.NearestNeighbors(*, n_neighbors=5, radius=1.0, algorithm='auto', leaf_size=30, metric='minkowski', p=2, metric_params=None, n_jobs=None)](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.NearestNeighbors.html#sklearn.neighbors.NearestNeighbors)

# %% [markdown]
# **Exercice 3-1 - Quel est l'id correspondant à la page Wikipedia de barack Obama ?**

# %%
# Compléter cette cellule ~ 1 ligne de code

# %%
#wiki['name'] == 'Barack Obama'
wiki[wiki['name'] == 'Barack Obama']
# Out:
#                                               URI          name  \
# id
# 35817  <http://dbpedia.org/resource/Barack_Obama>  Barack Obama
#
#                                                     text
# id
# 35817  barack hussein obama ii brk husen bm born augu...

# %% [markdown]
# **Exercice 3-2 - À l'aide de scikit-learn, rechercher les 10 pages Wikipedia de personnalités les plus similaires à la page de Barack Obama. Affichez les distances et noms de personalités dans une même trame de données**

# %%
# Compléter cette cellule ~ 5-6 lignes de code

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors(metric='euclidean', algorithm='brute').fit(word_count)
distances, indices = model.kneighbors(word_count[35817], n_neighbors=10)

# %%
indices
# Out:
# array([[35817, 24478, 28447, 35357, 14754, 13229, 31423, 22745, 36364,
#          9210]])

# %%
neighbors = pd.DataFrame({'distance':distances.flatten(), 'id':indices.flatten()}).set_index('id')
wiki.join(neighbors, on='id', how="right").sort_values(by='distance')[['name','distance']]
# Out:
#                              name   distance
# id
# 35817                Barack Obama   0.000000
# 24478                   Joe Biden  33.075671
# 28447              George W. Bush  34.394767
# 35357            Lawrence Summers  36.152455
# 14754                 Mitt Romney  36.166283
# 13229            Francisco Barrio  36.331804
# 31423              Walter Mondale  36.400549
# 22745  Wynn Normington Hugh-Jones  36.496575
# 36364                  Don Bonker  36.633318
# 9210                 Andy Anstett  36.959437

# %% [markdown]
# **Exercice 3-3 - Interprétez les résultats ci-dessus**

# %%
# Compléter cette cellule

# %% [markdown]
# Les 10 personnalités sont toutes des politiciens, mais à peu près la moitié d'entre elles ont des liens assez ténus avec Obama, outre le fait qu'ils sont des politiciens.
#
# * Francisco Barrio est un homme politique mexicain et ancien gouverneur de Chihuahua.
# * Walter Mondale et Don Bonker sont des démocrates qui ont fait carrière à la fin des années 1970.
# * Wynn Normington Hugh-Jones est un ancien diplomate britannique et fonctionnaire du Parti libéral.
# * Andy Anstett est un ancien politicien au Manitoba, au Canada.

# %% [markdown]
# **Exercice 3-4 - Affichez les mots les plus fréquents des pages de Barack Obama et Francisco Barrio**

# %% [markdown]
# Afin de pouvoir reconnaître rapidement les mots d'une grande importance, la fonction suivante permettant d'obtenir la colonne `word_count` est fournie.

# %%
def unpack_dict(matrix, map_index_to_word):
    table = sorted(map_index_to_word, key=map_index_to_word.get)
   
    data = matrix.data
    indices = matrix.indices
    indptr = matrix.indptr
    
    num_doc = matrix.shape[0]

    return [{k:v for k,v in zip([table[word_id] for word_id in indices[indptr[i]:indptr[i+1]] ],
                                 data[indptr[i]:indptr[i+1]].tolist())} for i in range(num_doc) ]

# %%
# Compléter cette cellule ~ 2 lignes de code

# %%
wiki['word_count'] = unpack_dict(word_count, map_index_to_word)
wiki['word_count'].iloc[35817]
# Out:
# {'husen': 1,
#  '2012obama': 1,
#  'laureateduring': 1,
#  'normalize': 1,
#  'brk': 1,
#  'doddfrank': 1,
#  'obamacare': 1,
#  'reauthorization': 1,
#  'reinvestment': 1,
#  'rodham': 1,
#  'stimulus': 1,
#  'briefs': 1,
#  'taxpayer': 1,
#  'repeal': 1,
#  'troop': 1,
#  'bm': 1,
#  '44th': 1,
#  'proposition': 1,
#  'romney': 1,
#  'unconstitutional': 1,
#  'mitt': 1,
#  'mccain': 1,
#  'gains': 1,
#  'laden': 1,
#  'primaries': 1,
#  'recession': 1,
#  'unemployment': 1,
#  'osama': 1,
#  'sufficient': 1,
#  'libya': 1,
#  'hook': 1,
#  'inaugurated': 1,
#  'withdrawal': 1,
#  '2000in': 1,
#  'urged': 1,
#  'delegates': 1,
#  'affordable': 1,
#  'hussein': 1,
#  'hillary': 1,
#  'californias': 1,
#  'treaty': 1,
#  'honolulu': 1,
#  'lengthy': 1,
#  'patient': 1,
#  'bin': 1,
#  'debt': 1,
#  'republicans': 1,
#  'lgbt': 1,
#  'regained': 1,
#  'ask': 1,
#  'organizer': 1,
#  'sandy': 1,
#  'keynote': 1,
#  'limit': 1,
#  'equality': 1,
#  'gun': 1,
#  '63': 1,
#  'recovery': 1,
#  'nobel': 1,
#  'barack': 1,
#  'arms': 1,
#  'strike': 1,
#  'cuba': 1,
#  'seats': 1,
#  'sworn': 1,
#  'elementary': 1,
#  '13th': 1,
#  'combat': 1,
#  'initiatives': 1,
#  'ordered': 3,
#  'unsuccessfully': 1,
#  'obama': 9,
#  'hawaii': 1,
#  'tell': 1,
#  'address': 1,
#  'islamic': 1,
#  'debate': 1,
#  'americans': 1,
#  'consumer': 1,
#  'increased': 1,
#  'whether': 1,
#  'nominee': 2,
#  'afghanistan': 2,
#  'filed': 1,
#  'legislation': 1,
#  'shooting': 1,
#  'raise': 1,
#  'policies': 1,
#  'levels': 1,
#  'insurance': 1,
#  'ending': 1,
#  'tax': 1,
#  'clinton': 1,
#  'constitutional': 1,
#  'budget': 1,
#  'domestic': 2,
#  'receive': 1,
#  'iraq': 4,
#  'relief': 2,
#  'convention': 1,
#  'operation': 1,
#  'protection': 2,
#  'sought': 1,
#  'defeating': 1,
#  'response': 3,
#  'involvement': 3,
#  'referred': 1,
#  'represent': 1,
#  'spending': 1,
#  'hold': 1,
#  'dont': 2,
#  'marriage': 1,
#  'reform': 1,
#  'creation': 1,
#  'russia': 1,
#  'wall': 1,
#  'resulted': 1,
#  'care': 1,
#  'supreme': 1,
#  'earning': 1,
#  'terms': 1,
#  'operations': 1,
#  'defense': 1,
#  'peace': 1,
#  'nomination': 1,
#  'process': 1,
#  'representatives': 2,
#  'illinois': 2,
#  'related': 1,
#  'control': 4,
#  'presidential': 2,
#  'reelected': 1,
#  'attorney': 1,
#  'republican': 2,
#  'african': 1,
#  'close': 1,
#  'representing': 1,
#  'promoted': 1,
#  'act': 8,
#  'job': 1,
#  'relations': 1,
#  'attention': 1,
#  'defeated': 1,
#  'senate': 3,
#  'victory': 1,
#  'nations': 1,
#  'primary': 2,
#  'running': 1,
#  'ended': 1,
#  'civil': 1,
#  '1961': 1,
#  'harvard': 2,
#  'ii': 1,
#  'administration': 1,
#  'start': 1,
#  'military': 4,
#  'total': 1,
#  'economic': 1,
#  'nine': 1,
#  'street': 1,
#  'form': 1,
#  'columbia': 1,
#  'review': 1,
#  'foreign': 2,
#  'death': 1,
#  'term': 3,
#  'democratic': 4,
#  'federal': 1,
#  'rights': 1,
#  'policy': 2,
#  'months': 1,
#  'campaign': 3,
#  'full': 1,
#  'down': 1,
#  'chicago': 2,
#  'court': 1,
#  'often': 1,
#  'taught': 1,
#  'current': 1,
#  'war': 1,
#  'district': 1,
#  'great': 1,
#  '8': 1,
#  'prize': 1,
#  'lost': 1,
#  'continued': 1,
#  'community': 1,
#  'graduate': 1,
#  'office': 2,
#  'election': 3,
#  'signed': 3,
#  'law': 6,
#  'included': 1,
#  '20': 2,
#  '4': 1,
#  'party': 3,
#  'house': 2,
#  '1992': 1,
#  'general': 1,
#  '1996': 1,
#  '1997': 1,
#  'called': 1,
#  'major': 1,
#  'named': 1,
#  'degree': 1,
#  'against': 1,
#  'august': 1,
#  'john': 1,
#  'november': 2,
#  'march': 1,
#  '2013': 1,
#  'july': 1,
#  'us': 6,
#  'or': 1,
#  'january': 3,
#  'while': 1,
#  'states': 3,
#  'president': 4,
#  '2012': 1,
#  'began': 1,
#  'state': 1,
#  '2011': 3,
#  '2004': 3,
#  'second': 2,
#  'into': 1,
#  '2010': 2,
#  'not': 1,
#  'united': 3,
#  '2009': 3,
#  'worked': 1,
#  'received': 1,
#  'served': 2,
#  'made': 1,
#  '2008': 1,
#  'before': 1,
#  'three': 1,
#  '2007': 1,
#  'over': 1,
#  'other': 1,
#  'then': 1,
#  'won': 1,
#  'during': 2,
#  'school': 3,
#  'national': 2,
#  'american': 3,
#  'two': 1,
#  'where': 1,
#  'years': 1,
#  'after': 4,
#  'new': 1,
#  'university': 2,
#  'which': 1,
#  'first': 3,
#  'that': 1,
#  'has': 4,
#  'by': 1,
#  'from': 3,
#  'born': 2,
#  'his': 11,
#  'at': 2,
#  'he': 7,
#  'with': 3,
#  'on': 2,
#  'as': 6,
#  'was': 5,
#  'for': 4,
#  'to': 14,
#  'is': 2,
#  'a': 7,
#  'of': 18,
#  'in': 30,
#  'and': 21,
#  'the': 40}

# %%
wiki
# Out:
#                                                      URI  \
# id
# 0            <http://dbpedia.org/resource/Digby_Morrell>
# 1           <http://dbpedia.org/resource/Alfred_J._Lewy>
# 2            <http://dbpedia.org/resource/Harpdog_Brown>
# 3      <http://dbpedia.org/resource/Franz_Rottensteiner>
# 4                   <http://dbpedia.org/resource/G-Enka>
# ...                                                  ...
# 59066           <http://dbpedia.org/resource/Olari_Elts>
# 59067       <http://dbpedia.org/resource/Scott_F._Crago>
# 59068  <http://dbpedia.org/resource/David_Cass_(footb...
# 59069          <http://dbpedia.org/resource/Keith_Elias>
# 59070         <http://dbpedia.org/resource/Fawaz_Damrah>
#
#                           name  \
# id
# 0                Digby Morrell
# 1               Alfred J. Lewy
# 2                Harpdog Brown
# 3          Franz Rottensteiner
# 4                       G-Enka
# ...                        ...
# 59066               Olari Elts
# 59067           Scott F. Crago
# 59068  David Cass (footballer)
# 59069              Keith Elias
# 59070             Fawaz Damrah
#
#                                                     text  \
# id
# 0      digby morrell born 10 october 1979 is a former...
# 1      alfred j lewy aka sandy lewy graduated from un...
# 2      harpdog brown is a singer and harmonica player...
# 3      franz rottensteiner born in waidmannsfeld lowe...
# 4      henry krvits born 30 december 1974 in tallinn ...
# ...                                                  ...
# 59066  olari elts born april 27 1971 in tallinn eston...
# 59067  scott francis crago born july 26 1963 twin bro...
# 59068  david william royce cass born 27 march 1962 in...
# 59069  keith hector elias born february 3 1972 in lac...
# 59070  fawaz mohammed damrah arabic fawwz damra was t...
#
#                                               word_count
# id
# 0      {'brisbaneafter': 1, 'edflhe': 1, 'aflfrom': 1...
# 1      {'maladaptation': 1, 'phasedelay': 1, '25hour'...
# 2      {'germanyover': 1, 'bluesgospel': 1, 'harpdog'...
# 3      {'fantasticrottensteiner': 1, 'waidmannsfeld':...
# 4      {'arhm': 3, 'gangstergenka': 1, 'kuhnja': 1, '...
# ...                                                  ...
# 59066  {'orchestraolaris': 1, 'ivth': 1, 'nyyd': 1, '...
# 59067  {'procushion': 1, '5088376': 1, 'trafton': 3, ...
# 59068  {'3257': 1, '15696': 1, 'grewcock': 1, 'orient...
# 59069  {'recordselias': 1, 'cochampionship': 1, 'xfl'...
# 59070  {'damra': 1, 'damrah': 4, 'fawwz': 1, 'trustee...
#
# [59071 rows x 4 columns]

# %% [markdown]
# **Exercice 3-5 - Créer une fonction `top_words`, permattant d'afficher les mots les plus fréquents d'une page donnée**

# %%
# Compléter cette cellule ~ 10 lignes de code

# %%
def top_words(name):
    """
    Retourne la table des mots les plus fréquents d'une page Wikipedia du jeu de données.
    """
    row = wiki[wiki['name'] == name]
    word_count_df = pd.DataFrame(row['word_count'].apply(pd.Series).stack(), columns=["count"]).droplevel(0)
    word_count_df.index.name = 'word'
    
    return word_count_df.sort_values(by='count', ascending=False)

# %%
def top_words(name):
    """
    Retourne la table des mots les plus fréquents d'une page Wikipedia du jeu de données.
    """
    row = wiki[wiki['name'] == name]
    
    
    return sorted(row['word_count'].iloc[0].items(), key=lambda x:x[1], reverse=True)

# %%
row = wiki[wiki['name'] == 'Francisco Barrio']
row['word_count'].iloc[0]
# Out:
# {'politicaldemocratic': 1,
#  'creelin': 1,
#  'satevo': 1,
#  'barrioterrazas': 1,
#  'itesmbarrio': 1,
#  'foxbarrio': 1,
#  'chihuahuas': 1,
#  'clothingin': 1,
#  'terrazas': 1,
#  'partyduring': 1,
#  'melndez': 1,
#  'baeza': 1,
#  'comptrollers': 1,
#  'favoritism': 1,
#  'groupon': 1,
#  'uninterrupted': 1,
#  'mayorship': 1,
#  'juarez': 2,
#  'jurez': 2,
#  'chihuahua': 7,
#  'barrio': 2,
#  'pri': 2,
#  'quitting': 1,
#  'raped': 1,
#  '20002003': 1,
#  'anticorruption': 1,
#  'partisan': 1,
#  'ciudad': 1,
#  'governorship': 1,
#  'vicente': 1,
#  'monterrey': 1,
#  'provocative': 1,
#  'surprising': 1,
#  'javier': 1,
#  'consequently': 1,
#  'autonomous': 1,
#  'deputies': 1,
#  'murdered': 1,
#  'secretariat': 1,
#  'murders': 1,
#  'arguing': 1,
#  'regained': 1,
#  'campaigned': 1,
#  'wore': 1,
#  'technological': 1,
#  'santiago': 1,
#  'walked': 1,
#  'accounting': 1,
#  'institutional': 1,
#  'fernando': 1,
#  'protests': 1,
#  'inquiry': 1,
#  'governance': 1,
#  'revolutionary': 1,
#  'interior': 1,
#  'delivered': 1,
#  'suggested': 1,
#  'pan': 2,
#  'affiliated': 1,
#  '80s': 1,
#  'expressed': 1,
#  'actions': 1,
#  'victims': 1,
#  'attacks': 1,
#  'mount': 1,
#  'transition': 1,
#  'governors': 1,
#  'mba': 1,
#  'ending': 1,
#  'refused': 1,
#  'ranks': 1,
#  'places': 1,
#  'rise': 1,
#  'hundreds': 1,
#  'mexican': 2,
#  'mixed': 1,
#  'headed': 1,
#  'sector': 1,
#  'partys': 1,
#  'consulting': 1,
#  'chapter': 1,
#  'controversy': 1,
#  'dark': 1,
#  'results': 1,
#  '60': 1,
#  'attempt': 1,
#  'towards': 1,
#  'higher': 1,
#  'ambassador': 1,
#  'controversial': 1,
#  'conducted': 1,
#  'parliamentary': 1,
#  'cabinet': 1,
#  'opposition': 1,
#  'process': 1,
#  '1950': 1,
#  'control': 2,
#  'presidential': 1,
#  'mexico': 1,
#  'chamber': 1,
#  'prestigious': 1,
#  'tenure': 1,
#  'mayor': 1,
#  'placed': 1,
#  'bachelors': 1,
#  'elections': 1,
#  'organizations': 1,
#  'action': 3,
#  'according': 1,
#  'annual': 1,
#  'course': 1,
#  'governor': 6,
#  'met': 1,
#  'night': 1,
#  'francisco': 1,
#  'native': 1,
#  'review': 1,
#  'leadership': 1,
#  'roles': 1,
#  'joining': 1,
#  'interest': 1,
#  'candidate': 2,
#  'term': 1,
#  'federal': 1,
#  'good': 1,
#  'women': 1,
#  'rights': 1,
#  'ran': 1,
#  'months': 1,
#  'private': 1,
#  'few': 1,
#  'secretary': 1,
#  'ever': 1,
#  'recent': 1,
#  'post': 1,
#  'becoming': 2,
#  'because': 1,
#  '24': 1,
#  'members': 1,
#  'minister': 1,
#  '25': 1,
#  'due': 1,
#  'leader': 1,
#  'lost': 1,
#  '7': 1,
#  'canada': 2,
#  'country': 1,
#  'another': 1,
#  'politician': 1,
#  'local': 1,
#  '1983': 1,
#  'win': 1,
#  '1986': 1,
#  'six': 1,
#  'end': 1,
#  'party': 3,
#  'studies': 1,
#  'political': 1,
#  'did': 1,
#  '1992': 1,
#  'elected': 1,
#  'some': 1,
#  'institute': 1,
#  'held': 2,
#  'history': 1,
#  'february': 1,
#  '1998': 1,
#  'than': 1,
#  'named': 1,
#  'degree': 1,
#  'against': 1,
#  'november': 1,
#  'july': 1,
#  'january': 1,
#  'while': 1,
#  'states': 1,
#  'president': 1,
#  '2003': 1,
#  'state': 4,
#  'its': 1,
#  'more': 1,
#  '2005': 1,
#  'not': 1,
#  '2009': 1,
#  'worked': 1,
#  'received': 1,
#  'served': 2,
#  'were': 2,
#  'made': 1,
#  'before': 2,
#  'later': 2,
#  'most': 1,
#  'won': 1,
#  'former': 3,
#  'became': 1,
#  'during': 2,
#  'career': 1,
#  'this': 1,
#  'member': 1,
#  'national': 3,
#  'where': 1,
#  'years': 3,
#  'one': 2,
#  'university': 1,
#  'first': 3,
#  'has': 1,
#  'by': 2,
#  'an': 2,
#  'from': 4,
#  'born': 2,
#  'his': 5,
#  'at': 2,
#  'he': 10,
#  'with': 1,
#  'on': 1,
#  'as': 5,
#  'was': 4,
#  'for': 3,
#  'to': 9,
#  'is': 2,
#  'a': 6,
#  'of': 24,
#  'in': 17,
#  'and': 18,
#  'the': 36}

# %%
obama_words = top_words('Barack Obama')
barrio_words = top_words('Francisco Barrio')
#combined_words = obama_words.join(barrio_words, on='word', how="inner", lsuffix='_obama', rsuffix='_barrio')
#combined_words.head(10)
obama_words
# Out:
# [('the', 40),
#  ('in', 30),
#  ('and', 21),
#  ('of', 18),
#  ('to', 14),
#  ('his', 11),
#  ('obama', 9),
#  ('act', 8),
#  ('he', 7),
#  ('a', 7),
#  ('law', 6),
#  ('us', 6),
#  ('as', 6),
#  ('was', 5),
#  ('iraq', 4),
#  ('control', 4),
#  ('military', 4),
#  ('democratic', 4),
#  ('president', 4),
#  ('after', 4),
#  ('has', 4),
#  ('for', 4),
#  ('ordered', 3),
#  ('response', 3),
#  ('involvement', 3),
#  ('senate', 3),
#  ('term', 3),
#  ('campaign', 3),
#  ('election', 3),
#  ('signed', 3),
#  ('party', 3),
#  ('january', 3),
#  ('states', 3),
#  ('2011', 3),
#  ('2004', 3),
#  ('united', 3),
#  ('2009', 3),
#  ('school', 3),
#  ('american', 3),
#  ('first', 3),
#  ('from', 3),
#  ('with', 3),
#  ('nominee', 2),
#  ('afghanistan', 2),
#  ('domestic', 2),
#  ('relief', 2),
#  ('protection', 2),
#  ('dont', 2),
#  ('representatives', 2),
#  ('illinois', 2),
#  ('presidential', 2),
#  ('republican', 2),
#  ('primary', 2),
#  ('harvard', 2),
#  ('foreign', 2),
#  ('policy', 2),
#  ('chicago', 2),
#  ('office', 2),
#  ('20', 2),
#  ('house', 2),
#  ('november', 2),
#  ('second', 2),
#  ('2010', 2),
#  ('served', 2),
#  ('during', 2),
#  ('national', 2),
#  ('university', 2),
#  ('born', 2),
#  ('at', 2),
#  ('on', 2),
#  ('is', 2),
#  ('husen', 1),
#  ('2012obama', 1),
#  ('laureateduring', 1),
#  ('normalize', 1),
#  ('brk', 1),
#  ('doddfrank', 1),
#  ('obamacare', 1),
#  ('reauthorization', 1),
#  ('reinvestment', 1),
#  ('rodham', 1),
#  ('stimulus', 1),
#  ('briefs', 1),
#  ('taxpayer', 1),
#  ('repeal', 1),
#  ('troop', 1),
#  ('bm', 1),
#  ('44th', 1),
#  ('proposition', 1),
#  ('romney', 1),
#  ('unconstitutional', 1),
#  ('mitt', 1),
#  ('mccain', 1),
#  ('gains', 1),
#  ('laden', 1),
#  ('primaries', 1),
#  ('recession', 1),
#  ('unemployment', 1),
#  ('osama', 1),
#  ('sufficient', 1),
#  ('libya', 1),
#  ('hook', 1),
#  ('inaugurated', 1),
#  ('withdrawal', 1),
#  ('2000in', 1),
#  ('urged', 1),
#  ('delegates', 1),
#  ('affordable', 1),
#  ('hussein', 1),
#  ('hillary', 1),
#  ('californias', 1),
#  ('treaty', 1),
#  ('honolulu', 1),
#  ('lengthy', 1),
#  ('patient', 1),
#  ('bin', 1),
#  ('debt', 1),
#  ('republicans', 1),
#  ('lgbt', 1),
#  ('regained', 1),
#  ('ask', 1),
#  ('organizer', 1),
#  ('sandy', 1),
#  ('keynote', 1),
#  ('limit', 1),
#  ('equality', 1),
#  ('gun', 1),
#  ('63', 1),
#  ('recovery', 1),
#  ('nobel', 1),
#  ('barack', 1),
#  ('arms', 1),
#  ('strike', 1),
#  ('cuba', 1),
#  ('seats', 1),
#  ('sworn', 1),
#  ('elementary', 1),
#  ('13th', 1),
#  ('combat', 1),
#  ('initiatives', 1),
#  ('unsuccessfully', 1),
#  ('hawaii', 1),
#  ('tell', 1),
#  ('address', 1),
#  ('islamic', 1),
#  ('debate', 1),
#  ('americans', 1),
#  ('consumer', 1),
#  ('increased', 1),
#  ('whether', 1),
#  ('filed', 1),
#  ('legislation', 1),
#  ('shooting', 1),
#  ('raise', 1),
#  ('policies', 1),
#  ('levels', 1),
#  ('insurance', 1),
#  ('ending', 1),
#  ('tax', 1),
#  ('clinton', 1),
#  ('constitutional', 1),
#  ('budget', 1),
#  ('receive', 1),
#  ('convention', 1),
#  ('operation', 1),
#  ('sought', 1),
#  ('defeating', 1),
#  ('referred', 1),
#  ('represent', 1),
#  ('spending', 1),
#  ('hold', 1),
#  ('marriage', 1),
#  ('reform', 1),
#  ('creation', 1),
#  ('russia', 1),
#  ('wall', 1),
#  ('resulted', 1),
#  ('care', 1),
#  ('supreme', 1),
#  ('earning', 1),
#  ('terms', 1),
#  ('operations', 1),
#  ('defense', 1),
#  ('peace', 1),
#  ('nomination', 1),
#  ('process', 1),
#  ('related', 1),
#  ('reelected', 1),
#  ('attorney', 1),
#  ('african', 1),
#  ('close', 1),
#  ('representing', 1),
#  ('promoted', 1),
#  ('job', 1),
#  ('relations', 1),
#  ('attention', 1),
#  ('defeated', 1),
#  ('victory', 1),
#  ('nations', 1),
#  ('running', 1),
#  ('ended', 1),
#  ('civil', 1),
#  ('1961', 1),
#  ('ii', 1),
#  ('administration', 1),
#  ('start', 1),
#  ('total', 1),
#  ('economic', 1),
#  ('nine', 1),
#  ('street', 1),
#  ('form', 1),
#  ('columbia', 1),
#  ('review', 1),
#  ('death', 1),
#  ('federal', 1),
#  ('rights', 1),
#  ('months', 1),
#  ('full', 1),
#  ('down', 1),
#  ('court', 1),
#  ('often', 1),
#  ('taught', 1),
#  ('current', 1),
#  ('war', 1),
#  ('district', 1),
#  ('great', 1),
#  ('8', 1),
#  ('prize', 1),
#  ('lost', 1),
#  ('continued', 1),
#  ('community', 1),
#  ('graduate', 1),
#  ('included', 1),
#  ('4', 1),
#  ('1992', 1),
#  ('general', 1),
#  ('1996', 1),
#  ('1997', 1),
#  ('called', 1),
#  ('major', 1),
#  ('named', 1),
#  ('degree', 1),
#  ('against', 1),
#  ('august', 1),
#  ('john', 1),
#  ('march', 1),
#  ('2013', 1),
#  ('july', 1),
#  ('or', 1),
#  ('while', 1),
#  ('2012', 1),
#  ('began', 1),
#  ('state', 1),
#  ('into', 1),
#  ('not', 1),
#  ('worked', 1),
#  ('received', 1),
#  ('made', 1),
#  ('2008', 1),
#  ('before', 1),
#  ('three', 1),
#  ('2007', 1),
#  ('over', 1),
#  ('other', 1),
#  ('then', 1),
#  ('won', 1),
#  ('two', 1),
#  ('where', 1),
#  ('years', 1),
#  ('new', 1),
#  ('which', 1),
#  ('that', 1),
#  ('by', 1)]

# %% [markdown]
# ## 4 - Recherche des plus proches voisins avec représentation TF-IDF

# %% [markdown]
# **Exercice 4 - Répétez les étapes des exercices de la partie 3 en utilisant cette fois-ci la représentation TF-IDF. Comparez avec les résultats obtenu par la représentation word count**

# %%
# Compléter cette cellule ~ 14-20 lignes de code

# %%
# Chargement des représentations TF-IDF
tf_idf = load_sparse_csr('../../data/people/people_wiki_tf_idf.npz')

# Recherche des 10 plus proches voisins
model_tf_idf = NearestNeighbors(metric='euclidean', algorithm='brute').fit(tf_idf)
distances, indices = model_tf_idf.kneighbors(tf_idf[35817], n_neighbors=10)

# Préparation de la trame de données des résultats
neighbors = pd.DataFrame({'distance':distances.flatten(), 'id':indices.flatten()}).set_index('id')
wiki.join(neighbors, on='id', how='right').sort_values(by='distance')[['name','distance']]

# %%
# Affichage des mots les plus significatifs des deux pages
wiki['tf_idf'] = unpack_dict(tf_idf, map_index_to_word)
def top_words_tf_idf(name):
    row = wiki[wiki['name'] == name]
    tf_idf_df = pd.DataFrame(row['tf_idf'].apply(pd.Series).stack(), columns=["weight"]).droplevel(0)
    tf_idf_df.index.name = 'word'
    return tf_idf_df.sort_values(by='weight', ascending=False)

obama_words = top_words_tf_idf('Barack Obama')
barrio_words = top_words_tf_idf('Francisco Barrio')
combined_words = obama_words.join(barrio_words, on='word', how="inner", lsuffix='_obama', rsuffix='_barrio')
combined_words.head(10)

# %% [markdown]
# ### Fin de l'atelier 02-02-A1
