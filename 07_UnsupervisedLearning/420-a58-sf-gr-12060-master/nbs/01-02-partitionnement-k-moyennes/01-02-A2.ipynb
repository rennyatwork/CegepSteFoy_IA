# %% [markdown]
# **420-A58-SF - Algorithmes d'apprentissage non supervisé - Hiver 2023 - Spécialisation technique en Intelligence Artificielle**<br/>
# MIT License - Copyright (c) 2023 Mikaël Swawola
# <br/>
# ![Travaux Pratiques - partitionnement-k-moyennes (sklearn)](static/01-02-A2-banner.png)
# <br/>
# **Objectif:** cet atelier a pour objectif la mise en oeuvre du partitionnement K-moyennes à l'aide de la librairie scikit-learn

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## 1 - Lecture et visualisation des données

# %%
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# Chargement des données
blobs = pd.read_csv('../../data/blobs.csv')

# Configuration de la visualisation
sns.set(style="darkgrid")
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
plt.rcParams['figure.figsize']=(12,8)
_ = sns.scatterplot(x="x0", y="x1", data=blobs)
plt.xlabel('x0')
plt.ylabel('x1')
# Out:
# Text(0, 0.5, 'x1')

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ## 2 - Mise en oeuvre du partitionnement K-moyennes avec scikit-learn

# %% [markdown]
# **Exercice 1-1 - Initialiser la variable K, représentant le nombre de clusters estimé à partir de la visualisation précédente**

# %%
# Compléter cette cellule ~ 1 ligne de code

# %% [markdown]
# **Exercice 1-2 - À l'aide de scikit-learn, effectuer le partitionnement K-moyennes**

# %% [markdown]
# [class sklearn.cluster.KMeans(n_clusters=8, *, init='k-means++', n_init=10, max_iter=300, tol=0.0001, precompute_distances='deprecated', verbose=0, random_state=None, copy_x=True, n_jobs='deprecated', algorithm='auto')](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)

# %%
# Compléter cette cellule ~ 3-5 lignes de code
n_clusters=5
kmeans = KMeans(n_clusters=n_clusters, random_state=2023, n_init='auto').fit(blobs)

# %% [markdown]
# **Exercice 1-3 - Afficher les centroïdes et les "labels" (ou indices, c) de chaque observation**

# %%
# Compléter cette cellule ~ 2-4 lignes de code
print(kmeans.cluster_centers_)
print(kmeans.labels_)
# Out:
# [[  5.07912689   5.18450447]
#  [  5.07034894 -10.01987585]
#  [  9.77709653   0.53310078]
#  [  3.90314304  -8.8910588 ]
#  [  6.45429625   4.17675593]]
# [2 3 4 2 4 0 0 2 1 3 0 0 2 1 1 2 0 1 2 4 0 2 3 0 3 0 0 1 3 0 4 2 3 3 3 2 4
#  4 2 4 1 3 4 1 4 2 2 1 2 0 1 1 3 2 3 2 2 3 4 2 4 3 0 0 4 1 2 2 4 2 2 1 2 2
#  2 2 2 0 2 3 2 4 4 4 0 3 2 2 0 0 3 2 4 4 0 3 2 4 0 2 2 0 4 4 3 0 2 2 2 3 0
#  4 4 2 0 4 2 2 4 2 2 0 1 4 2 4 4 3 2 4 0 0 1 0 0 1 1 1 1 2 2 3 2 4 0 2 1 1
#  3 4 3 2 3 2 4 1 3 2 4 3 1 0 2 4 3 1 4 0 2 0 2 1 2 3 4 2 3 2 2 4 0 2 3 1 1
#  3 1 3 2 0 2 2 4 3 2 0 1 3 2 0 1 2 2 3 3 2 1 2 3 3 2 0 4 1 2 2 1 2 2 0 1 1
#  0 3 3 4 2 4 2 3 2 2 0 4 0 3 2 4 4 2 0 3 2 2 2 2 2 3 1 2 3 3 2 2 2 3 1 2 2
#  3 3 3 0 4 3 0 0 1 3 4 0 1 4 2 2 4 4 4 0 1 0 2 2 4 0 2 3 3 3 1 1 0 1 0 4 1
#  4 1 4 0 4 2 4 4 2 1 1 4 0 2 3 0 1 4 2 2 1 2 1 2 0 0 0 0 3 1 2 0 0 3 4 0 2
#  2 0 1 2 2 3 0 2 2 4 0 2 4 1 2 1 2 0 0 2 1 2 2 3 4 4 0 1 1 0 3 0 0 3 3 3 1
#  0 0 2 0 1 2 2 2 1 0 2 2 2 0 4 4 2 3 3 2 4 0 4 2 0 0 3 2 3 2 2 3 4 3 4 2 0
#  2 1 1 2 4 1 2 1 4 0 1 0 3 4 0 1 3 3 3 3 4 2 2 1 4 2 3 0 1 3 0 1 4 0 2 2 4
#  2 2 0 2 1 4 4 1 3 1 2 2 4 4 3 4 4 0 4 1 1 4 2 2 1 0 0 2 2 1 3 2 4 4 3 0 2
#  3 3 2 2 3 0 1 2 2 3 1 2 0 1 1 1 1 3 4 0 1 2 0 1 2 0 2 1 2 4 1 3 4 3 2 4 2
#  1 1 4 2 0 4 0 4 3 2 4 3 3 2 4 1 0 3 2 3 2 2 0 0 0 2 3 1 1 4 2 1 2 3 1 2 2
#  2 2 2 2 3 2 3 2 3 2 1 1 1 4 1 4 0 1 4 0 2 1 1 0 2 2 3 3 3 0 0 2 3 3 3 0 2
#  0 2 1 3 1 1 1 3 0 3 2 4 2 3 4 2 2 4 2 4 4 0 3 4 4 1 4 1 2 2 2 4 4 0 2 2 0
#  2 1 4 0 3 1 0 2 3 2 2 3 2 4 2 3 2 2 4 3 2 4 0 2 1 3 0 0 4 3 2 2 2 2 2 4 2
#  1 2 2 1 1 4 1 2 3 3 1 4 2 2 2 2 2 4 2 2 2 4 2 3 3 2 1 2 2 4 2 0 1 4 2 1 4
#  2 0 4 4 0 4 2 1 3 4 3 0 2 2 0 0 0 0 2 2 2 2 2 1 1 4 4 2 2 0 1 4 4 1 2 1 2
#  4 2 3 2 3 2 3 1 3 2 0 4 2 3 2 0 2 0 2 4 4 2 2 2 2 2 3 1 0 3 2 0 3 2 2 1 2
#  3 2 2 3 0 4 2 3 0 1 1 3 3 1 3 0 2 3 3 2 4 2 3 2 2 3 3 2 2 4 1 2 2 2 1 0 1
#  2 1 2 2 3 1 4 2 2 3 0 0 2 4 3 1 2 2 2 2 2 0 2 0 4 3 0 2 2 0 0 2 4 3 1 1 3
#  2 3 1 2 0 1 1 1 2 3 1 4 0 2 2 1 2 4 4 4 0 2 2 0 1 1 4 3 0 4 3 3 1 0 4 4 3
#  0 4 2 4 4 0 4 0 4 1 2 2 3 2 2 2 3 3 0 4 4 0 2 4 2 1 2 0 2 2 2 3 3 2 0 4 3
#  2 3 4 0 2 0 3 2 0 0 3 3 3 3 2 0 2 2 1 2 1 2 4 2 3 3 2 0 2 4 4 2 2 2 4 0 1
#  4 2 3 1 4 3 4 0 0 1 2 2 1 1 3 1 2 3 2 3 3 1 4 2 2 1 2 0 2 4 1 1 2 2 3 0 2
#  3]

# %%
print(len(kmeans.labels_))
print(len(blobs))
# Out:
# 1000
# 1000

# %%
blobs
# Out:
#             x0         x1
# 0    10.947841   2.028498
# 1     3.675247 -10.206901
# 2     5.809632   4.076479
# 3     8.053083   1.129893
# 4     5.681480   4.405307
# ..         ...        ...
# 995   8.770883  -0.006383
# 996   3.638953  -9.169461
# 997   5.560394   4.679340
# 998   8.805843   1.299326
# 999   3.472746  -8.650870
#
# [1000 rows x 2 columns]

# %%
sns.scatterplot(data=blobs, x='x0', y='x1')
# Out:
# <AxesSubplot: xlabel='x0', ylabel='x1'>

# %% [markdown]
# **Fin de l'atelier 01-02-A2**
