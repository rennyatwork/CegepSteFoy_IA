# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import statsmodels.api as stm
import statsmodels.stats.weightstats as ws
import sklearn.linear_model as sk_lin_mod
import math
import seaborn as sns
import os
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
#import sys
#!{sys.executable} -m pip install --upgrade ipykernel
#!{sys.executable} -m pip install --upgrade pandas
#!{sys.executable} -m pip install --upgrade  sickit-learn

# %%
import PyQt5 #works
from PyQt5 import QtCore, QtGui, QtWidgets #works for pyqt5
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x7f9fc670cb40>

# %%
os.getcwd()
# Out:
# '/home/hadoop/Git_Ia/CegepSteFoy_IA/04_Eda/TP02'

# %%
print (os.getcwd())
currDir = os.getcwd()
fullPath = currDir + "/CabaneASucrev0r3.csv"
type(currDir)
# Out:
# /home/hadoop/Git_Ia/CegepSteFoy_IA/04_Eda/TP02
# str

# %%
donnee = pd.read_csv(fullPath)
stats=donnee.describe()
dimensions=donnee.shape
stats
# Out:
#              Année  Jour Calendrier Saison  Temp max.(°C)  Temp min.(°C)  \
# count  1875.000000             1875.000000     1873.00000    1875.000000
# mean   2010.000000               45.144000        1.51543      -8.633867
# std       6.059559               25.781811        7.63530       8.695859
# min    2000.000000                1.000000      -22.60000     -34.800000
# 25%    2005.000000               23.000000       -3.60000     -15.100000
# 50%    2010.000000               45.000000        1.70000      -6.700000
# 75%    2015.000000               67.000000        6.40000      -1.450000
# max    2020.000000               90.000000       27.50000      10.000000
#
#        Temp moy.(°C)  Diff Temp (°C)  Précip. tot. (mm)  \
# count    1873.000000     1875.000000        1872.000000
# mean       -3.557768       10.147680           2.738568
# std         7.843854        4.770659           5.574896
# min       -25.700000        0.900000           0.000000
# 25%        -9.300000        6.700000           0.000000
# 50%        -2.500000        9.600000           0.000000
# 75%         2.400000       13.100000           2.600000
# max        18.800000       31.000000          41.600000
#
#        Précip. Tot. Hiver (mm)  Nombre épisodes gel/dégel  \
# count              1875.000000                1875.000000
# mean                610.334347                  20.633067
# std                 126.965290                   5.251394
# min                 313.200000                  14.000000
# 25%                 536.400000                  16.000000
# 50%                 620.300000                  20.000000
# 75%                 685.100000                  25.000000
# max                 811.700000                  30.000000
#
#        Production moyenne par entaille (L)  ...     Pixel6_B     Pixel7_R  \
# count                          1875.000000  ...  1875.000000  1875.000000
# mean                             26.523733  ...    33.771435   157.936992
# std                              10.234991  ...    26.416038    85.971146
# min                              11.567238  ...     0.000000     0.000000
# 25%                              17.280176  ...     8.345000   111.895000
# 50%                              26.462002  ...    32.970000   183.190000
# 75%                              34.315361  ...    55.820000   227.420000
# max                              46.784424  ...   108.800000   255.000000
#
#           Pixel7_G     Pixel7_B     Pixel8_R     Pixel8_G     Pixel8_B  \
# count  1875.000000  1875.000000  1875.000000  1875.000000  1875.000000
# mean     71.317269    32.709104   156.869221    70.605899    33.460053
# std      52.296358    26.692262    85.231625    52.970868    27.297388
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      32.555000     4.865000   111.960000    31.290000     5.545000
# 50%      71.920000    31.110000   180.810000    69.960000    31.410000
# 75%     102.465000    54.910000   224.955000   103.015000    56.400000
# max     255.000000   125.400000   255.000000   255.000000   117.940000
#
#           Pixel9_R     Pixel9_G     Pixel9_B
# count  1875.000000  1875.000000  1875.000000
# mean    157.787557    70.609437    32.820418
# std      85.760582    53.761268    27.040843
# min       0.000000     0.000000     0.000000
# 25%     109.940000    28.830373     4.326591
# 50%     183.020000    70.558732    31.111611
# 75%     225.820000   104.848430    55.027608
# max     255.000000   255.000000   132.121595
#
# [8 rows x 48 columns]

# %%
donnee.isnull().sum()
# Out:
# Date                                   0
# Année                                  0
# Jour Calendrier Saison                 0
# Temp max.(°C)                          2
# Temp min.(°C)                          0
# Temp moy.(°C)                          2
# Diff Temp (°C)                         0
# Précip. tot. (mm)                      3
# Précip. Tot. Hiver (mm)                0
# Nombre épisodes gel/dégel              0
# Production moyenne par entaille (L)    0
# Débit sève (L/j)                       0
# Sucre sève (%)                         0
# Alimentation osmoseur (L/j)            0
# Osmoseur (heures opération/j)          0
# Pression osmoseur (bar)                0
# Sucre sortie osmoseur (%)              0
# Température Bouilloire (0C)            0
# Temps bouilloire (h)                   0
# Sucre du sirop obtenu (%)              0
# Quantité de sirop obtenue (L)          0
# Transmittance produit (%)              0
# Pixel1_R                               0
# Pixel1_G                               0
# Pixel1_B                               0
# Pixel2_R                               0
# Pixel2_G                               0
# Pixel2_B                               0
# Pixel3_R                               0
# Pixel3_G                               0
# Pixel3_B                               0
# Pixel4_R                               0
# Pixel4_G                               0
# Pixel4_B                               0
# Pixel5_R                               0
# Pixel5_G                               0
# Pixel5_B                               0
# Pixel6_R                               0
# Pixel6_G                               0
# Pixel6_B                               0
# Pixel7_R                               0
# Pixel7_G                               0
# Pixel7_B                               0
# Pixel8_R                               0
# Pixel8_G                               0
# Pixel8_B                               0
# Pixel9_R                               0
# Pixel9_G                               0
# Pixel9_B                               0
# Classe Sirop                           0
# dtype: int64

# %% [markdown]
# Heureusement, très peu de nulls.
#
# Quels sont les enregistrements contenant des nulls?

# %%
donnee[(donnee['Temp max.(°C)'].isna()==True) | (donnee['Précip. tot. (mm)'].isna()==True)]
# Out:
#             Date  Année  Jour Calendrier Saison  Temp max.(°C)  Temp min.(°C)  \
# 1519  2017-02-02   2017                       2            NaN          -17.4
# 1524  2017-02-07   2017                       7            NaN          -25.1
# 1632  2018-02-26   2018                      26            3.2           -7.4
#
#       Temp moy.(°C)  Diff Temp (°C)  Précip. tot. (mm)  \
# 1519            NaN            17.4                NaN
# 1524            NaN            25.1                NaN
# 1632           -2.1            10.6                NaN
#
#       Précip. Tot. Hiver (mm)  Nombre épisodes gel/dégel  ...  Pixel7_R  \
# 1519                    770.6                         20  ...    224.35
# 1524                    770.6                         20  ...    255.00
# 1632                    811.7                         16  ...    213.40
#
#       Pixel7_G  Pixel7_B  Pixel8_R  Pixel8_G  Pixel8_B  Pixel9_R    Pixel9_G  \
# 1519    173.08     30.45    255.00    127.83     77.18    255.00  127.017170
# 1524    131.77      3.27    225.25    123.51     61.07    194.07   70.795317
# 1632    111.76      3.39    212.26     98.49     35.60    193.85  127.018875
#
#        Pixel9_B  Classe Sirop
# 1519  10.139073         Ambré
# 1524  71.603721         Foncé
# 1632  37.339503         Foncé
#
# [3 rows x 50 columns]

# %% [markdown]
# Fill na

# %%
donnee.fillna(method='bfill', inplace=True)
donnee.isnull().sum()
# Out:
# Date                                   0
# Année                                  0
# Jour Calendrier Saison                 0
# Temp max.(°C)                          0
# Temp min.(°C)                          0
# Temp moy.(°C)                          0
# Diff Temp (°C)                         0
# Précip. tot. (mm)                      0
# Précip. Tot. Hiver (mm)                0
# Nombre épisodes gel/dégel              0
# Production moyenne par entaille (L)    0
# Débit sève (L/j)                       0
# Sucre sève (%)                         0
# Alimentation osmoseur (L/j)            0
# Osmoseur (heures opération/j)          0
# Pression osmoseur (bar)                0
# Sucre sortie osmoseur (%)              0
# Température Bouilloire (0C)            0
# Temps bouilloire (h)                   0
# Sucre du sirop obtenu (%)              0
# Quantité de sirop obtenue (L)          0
# Transmittance produit (%)              0
# Pixel1_R                               0
# Pixel1_G                               0
# Pixel1_B                               0
# Pixel2_R                               0
# Pixel2_G                               0
# Pixel2_B                               0
# Pixel3_R                               0
# Pixel3_G                               0
# Pixel3_B                               0
# Pixel4_R                               0
# Pixel4_G                               0
# Pixel4_B                               0
# Pixel5_R                               0
# Pixel5_G                               0
# Pixel5_B                               0
# Pixel6_R                               0
# Pixel6_G                               0
# Pixel6_B                               0
# Pixel7_R                               0
# Pixel7_G                               0
# Pixel7_B                               0
# Pixel8_R                               0
# Pixel8_G                               0
# Pixel8_B                               0
# Pixel9_R                               0
# Pixel9_G                               0
# Pixel9_B                               0
# Classe Sirop                           0
# dtype: int64

# %%
donnee.columns
# Out:
# Index(['Date', 'Année', 'Jour Calendrier Saison', 'Temp max.(°C)',
#        'Temp min.(°C)', 'Temp moy.(°C)', 'Diff Temp (°C)', 'Précip. tot. (mm)',
#        'Précip. Tot. Hiver (mm)', 'Nombre épisodes gel/dégel',
#        'Production moyenne par entaille (L)', 'Débit sève (L/j)',
#        'Sucre sève (%)', 'Alimentation osmoseur (L/j)',
#        'Osmoseur (heures opération/j)', 'Pression osmoseur (bar)',
#        'Sucre sortie osmoseur (%)', 'Température Bouilloire (0C)',
#        'Temps bouilloire (h)', 'Sucre du sirop obtenu (%)',
#        'Quantité de sirop obtenue (L)', 'Transmittance produit (%)',
#        'Pixel1_R', 'Pixel1_G', 'Pixel1_B', 'Pixel2_R', 'Pixel2_G', 'Pixel2_B',
#        'Pixel3_R', 'Pixel3_G', 'Pixel3_B', 'Pixel4_R', 'Pixel4_G', 'Pixel4_B',
#        'Pixel5_R', 'Pixel5_G', 'Pixel5_B', 'Pixel6_R', 'Pixel6_G', 'Pixel6_B',
#        'Pixel7_R', 'Pixel7_G', 'Pixel7_B', 'Pixel8_R', 'Pixel8_G', 'Pixel8_B',
#        'Pixel9_R', 'Pixel9_G', 'Pixel9_B', 'Classe Sirop'],
#       dtype='object')

# %% [markdown]
# Supprimer les colonnes pixel

# %%
donnee.filter(like='Pixel').columns
dfSansPixel = donnee.drop(donnee.filter(like='Pixel').columns, axis=1)
dfSansPixel.columns
# Out:
# Index(['Date', 'Année', 'Jour Calendrier Saison', 'Temp max.(°C)',
#        'Temp min.(°C)', 'Temp moy.(°C)', 'Diff Temp (°C)', 'Précip. tot. (mm)',
#        'Précip. Tot. Hiver (mm)', 'Nombre épisodes gel/dégel',
#        'Production moyenne par entaille (L)', 'Débit sève (L/j)',
#        'Sucre sève (%)', 'Alimentation osmoseur (L/j)',
#        'Osmoseur (heures opération/j)', 'Pression osmoseur (bar)',
#        'Sucre sortie osmoseur (%)', 'Température Bouilloire (0C)',
#        'Temps bouilloire (h)', 'Sucre du sirop obtenu (%)',
#        'Quantité de sirop obtenue (L)', 'Transmittance produit (%)',
#        'Classe Sirop'],
#       dtype='object')

# %%
dfSansPixel.dtypes
# Out:
# Date                                    object
# Année                                    int64
# Jour Calendrier Saison                   int64
# Temp max.(°C)                          float64
# Temp min.(°C)                          float64
# Temp moy.(°C)                          float64
# Diff Temp (°C)                         float64
# Précip. tot. (mm)                      float64
# Précip. Tot. Hiver (mm)                float64
# Nombre épisodes gel/dégel                int64
# Production moyenne par entaille (L)    float64
# Débit sève (L/j)                       float64
# Sucre sève (%)                         float64
# Alimentation osmoseur (L/j)            float64
# Osmoseur (heures opération/j)          float64
# Pression osmoseur (bar)                float64
# Sucre sortie osmoseur (%)              float64
# Température Bouilloire (0C)            float64
# Temps bouilloire (h)                   float64
# Sucre du sirop obtenu (%)                int64
# Quantité de sirop obtenue (L)          float64
# Transmittance produit (%)              float64
# Classe Sirop                            object
# dtype: object

# %%
### liste de variables (colonnes) dépendantes
list_cols_dependennt_vars = []
col_debit_seve = dfSansPixel['Débit sève (L/j)'].name
col_sucre_dans_seve = dfSansPixel['Sucre sève (%)'].name
col_pct_transmittance = dfSansPixel['Transmittance produit (%)'].name
col_productivite_seve_par_saison = dfSansPixel['Production moyenne par entaille (L)'].name
list_cols_dependennt_vars = [col_debit_seve, col_sucre_dans_seve, col_pct_transmittance, col_productivite_seve_par_saison]

# %%
## convertir Classe Sirop en numérique - https://www.youtube.com/watch?v=wH_ezgftiy0&t=136s
dfSansPixel['CategClasseSirop'] = dfSansPixel['Classe Sirop'].astype('category').cat.codes
dfNumerique = dfSansPixel.select_dtypes(exclude='object').copy()
dfNumerique.dtypes
# Out:
# Année                                    int64
# Jour Calendrier Saison                   int64
# Temp max.(°C)                          float64
# Temp min.(°C)                          float64
# Temp moy.(°C)                          float64
# Diff Temp (°C)                         float64
# Précip. tot. (mm)                      float64
# Précip. Tot. Hiver (mm)                float64
# Nombre épisodes gel/dégel                int64
# Production moyenne par entaille (L)    float64
# Débit sève (L/j)                       float64
# Sucre sève (%)                         float64
# Alimentation osmoseur (L/j)            float64
# Osmoseur (heures opération/j)          float64
# Pression osmoseur (bar)                float64
# Sucre sortie osmoseur (%)              float64
# Température Bouilloire (0C)            float64
# Temps bouilloire (h)                   float64
# Sucre du sirop obtenu (%)                int64
# Quantité de sirop obtenue (L)          float64
# Transmittance produit (%)              float64
# CategClasseSirop                          int8
# dtype: object

# %% [markdown]
# ### Multiple Linear Regression
#
#
# https://www.geeksforgeeks.org/ml-multiple-linear-regression-using-python/
#
# Assumption of Regression Model :
#
# - Linearity: The relationship between dependent and independent variables should be linear.
# - Homoscedasticity: Constant variance of the errors should be maintained.
# - Multivariate normality: Multiple Regression assumes that the residuals are normally distributed.
# - Lack of Multicollinearity: It is assumed that there is little or no multicollinearity in

# %%
stats = dfNumerique.describe()
stats
# Out:
#              Année  Jour Calendrier Saison  Temp max.(°C)  Temp min.(°C)  \
# count  1875.000000             1875.000000    1875.000000    1875.000000
# mean   2010.000000               45.144000       1.507733      -8.633867
# std       6.059559               25.781811       7.636093       8.695859
# min    2000.000000                1.000000     -22.600000     -34.800000
# 25%    2005.000000               23.000000      -3.600000     -15.100000
# 50%    2010.000000               45.000000       1.700000      -6.700000
# 75%    2015.000000               67.000000       6.400000      -1.450000
# max    2020.000000               90.000000      27.500000      10.000000
#
#        Temp moy.(°C)  Diff Temp (°C)  Précip. tot. (mm)  \
# count    1875.000000     1875.000000        1875.000000
# mean       -3.565813       10.147680           2.738347
# std         7.844030        4.770659           5.572377
# min       -25.700000        0.900000           0.000000
# 25%        -9.300000        6.700000           0.000000
# 50%        -2.500000        9.600000           0.000000
# 75%         2.400000       13.100000           2.600000
# max        18.800000       31.000000          41.600000
#
#        Précip. Tot. Hiver (mm)  Nombre épisodes gel/dégel  \
# count              1875.000000                1875.000000
# mean                610.334347                  20.633067
# std                 126.965290                   5.251394
# min                 313.200000                  14.000000
# 25%                 536.400000                  16.000000
# 50%                 620.300000                  20.000000
# 75%                 685.100000                  25.000000
# max                 811.700000                  30.000000
#
#        Production moyenne par entaille (L)  ...  Alimentation osmoseur (L/j)  \
# count                          1875.000000  ...                  1875.000000
# mean                             26.523733  ...                  1038.447262
# std                              10.234991  ...                  1745.361854
# min                              11.567238  ...                     0.000000
# 25%                              17.280176  ...                   121.000000
# 50%                              26.462002  ...                   276.000000
# 75%                              34.315361  ...                   669.000000
# max                              46.784424  ...                 10664.616000
#
#        Osmoseur (heures opération/j)  Pression osmoseur (bar)  \
# count                    1875.000000              1875.000000
# mean                        2.336891                34.058421
# std                         3.928002                14.394987
# min                         0.000000                 0.000000
# 25%                         0.270000                37.720000
# 50%                         0.620000                39.600000
# 75%                         1.505000                41.120000
# max                        24.000000                46.590000
#
#        Sucre sortie osmoseur (%)  Température Bouilloire (0C)  \
# count                1875.000000                  1875.000000
# mean                    6.837088                    88.515555
# std                     3.418384                    37.097081
# min                     0.000000                     0.000000
# 25%                     5.720000                   103.823261
# 50%                     7.600000                   104.031253
# 75%                     9.120000                   104.209536
# max                    14.590000                   104.694042
#
#        Temps bouilloire (h)  Sucre du sirop obtenu (%)  \
# count           1875.000000                1875.000000
# mean               2.019547                  57.016533
# std                1.719075                  23.913916
# min                0.000000                   0.000000
# 25%                1.530000                  66.000000
# 50%                1.620000                  67.000000
# 75%                1.690000                  68.000000
# max               11.480000                  70.000000
#
#        Quantité de sirop obtenue (L)  Transmittance produit (%)  \
# count                    1875.000000                1875.000000
# mean                       74.689611                  37.075563
# std                       126.713112                  18.920109
# min                         0.000000                   0.000000
# 25%                         7.865000                  29.810000
# 50%                        19.200000                  40.700000
# 75%                        44.900000                  49.600000
# max                       681.990000                  82.520000
#
#        CategClasseSirop
# count       1875.000000
# mean           2.121067
# std            1.247306
# min            0.000000
# 25%            1.000000
# 50%            3.000000
# 75%            3.000000
# max            4.000000
#
# [8 rows x 22 columns]

# %%
#dfNumerique[dfNumerique['CategClasseSirop']==0 | dfNumerique['Pression osmoseur (bar)']==0].count()
dfNumerique[dfNumerique['Pression osmoseur (bar)']==0].count()
# Out:
# Année                                  280
# Jour Calendrier Saison                 280
# Temp max.(°C)                          280
# Temp min.(°C)                          280
# Temp moy.(°C)                          280
# Diff Temp (°C)                         280
# Précip. tot. (mm)                      280
# Précip. Tot. Hiver (mm)                280
# Nombre épisodes gel/dégel              280
# Production moyenne par entaille (L)    280
# Débit sève (L/j)                       280
# Sucre sève (%)                         280
# Alimentation osmoseur (L/j)            280
# Osmoseur (heures opération/j)          280
# Pression osmoseur (bar)                280
# Sucre sortie osmoseur (%)              280
# Température Bouilloire (0C)            280
# Temps bouilloire (h)                   280
# Sucre du sirop obtenu (%)              280
# Quantité de sirop obtenue (L)          280
# Transmittance produit (%)              280
# CategClasseSirop                       280
# dtype: int64

# %%
dfNumerique = dfNumerique.loc[dfNumerique['Pression osmoseur (bar)'] >0]

# %%
## sns tips
#sns.pairplot(dfNumerique)

# %%
## pour chaque var dépendant, une régression
#for col_y in list_cols_dependennt_vars:
#    sns.pairplot(dfNumerique, y_vars=col_y.name, kind='reg')

# %%
corr = dfNumerique.corr()
#sns.heatmap(corr, cbar=True, cmap="Blues", center=0, annot=True, fmt=".1f")

## le résultat est une matric 22x22 pas facile à visualiser

# %%
corr
# Out:
#                                         Année  Jour Calendrier Saison  \
# Année                                1.000000               -0.069027
# Jour Calendrier Saison              -0.069027                1.000000
# Temp max.(°C)                       -0.076255                0.732056
# Temp min.(°C)                       -0.151222                0.678497
# Temp moy.(°C)                       -0.120846                0.737940
# Diff Temp (°C)                       0.143382               -0.032841
# Précip. tot. (mm)                    0.068946                0.047551
# Précip. Tot. Hiver (mm)              0.770270               -0.108359
# Nombre épisodes gel/dégel            0.120394               -0.026489
# Production moyenne par entaille (L)  0.292406               -0.043370
# Débit sève (L/j)                     0.047838                0.286448
# Sucre sève (%)                      -0.116668               -0.036819
# Alimentation osmoseur (L/j)          0.039093                0.280341
# Osmoseur (heures opération/j)        0.039085                0.280338
# Pression osmoseur (bar)             -0.008857                0.050691
# Sucre sortie osmoseur (%)           -0.008857                0.050691
# Température Bouilloire (0C)          0.029629               -0.045762
# Temps bouilloire (h)                 0.051315                0.274606
# Sucre du sirop obtenu (%)            0.027543               -0.038425
# Quantité de sirop obtenue (L)        0.041213                0.281603
# Transmittance produit (%)            0.031924               -0.337132
# CategClasseSirop                    -0.017023                0.283606
#
#                                      Temp max.(°C)  Temp min.(°C)  \
# Année                                    -0.076255      -0.151222
# Jour Calendrier Saison                    0.732056       0.678497
# Temp max.(°C)                             1.000000       0.818663
# Temp min.(°C)                             0.818663       1.000000
# Temp moy.(°C)                             0.948860       0.957822
# Diff Temp (°C)                            0.142986      -0.450491
# Précip. tot. (mm)                         0.050561       0.207606
# Précip. Tot. Hiver (mm)                  -0.160530      -0.211713
# Nombre épisodes gel/dégel                 0.080940       0.090037
# Production moyenne par entaille (L)       0.058584       0.056036
# Débit sève (L/j)                          0.459293       0.160894
# Sucre sève (%)                            0.038611      -0.052988
# Alimentation osmoseur (L/j)               0.448579       0.159015
# Osmoseur (heures opération/j)             0.448560       0.159008
# Pression osmoseur (bar)                   0.039888       0.056696
# Sucre sortie osmoseur (%)                 0.039888       0.056696
# Température Bouilloire (0C)              -0.005782      -0.025731
# Temps bouilloire (h)                      0.435913       0.160151
# Sucre du sirop obtenu (%)                -0.001757      -0.020595
# Quantité de sirop obtenue (L)             0.448399       0.160767
# Transmittance produit (%)                -0.249899      -0.222120
# CategClasseSirop                          0.204277       0.188086
#
#                                      Temp moy.(°C)  Diff Temp (°C)  \
# Année                                    -0.120846        0.143382
# Jour Calendrier Saison                    0.737940       -0.032841
# Temp max.(°C)                             0.948860        0.142986
# Temp min.(°C)                             0.957822       -0.450491
# Temp moy.(°C)                             1.000000       -0.175748
# Diff Temp (°C)                           -0.175748        1.000000
# Précip. tot. (mm)                         0.140106       -0.279098
# Précip. Tot. Hiver (mm)                  -0.196109        0.116612
# Nombre épisodes gel/dégel                 0.089963       -0.029372
# Production moyenne par entaille (L)       0.060362       -0.004684
# Débit sève (L/j)                          0.317642        0.436422
# Sucre sève (%)                           -0.010115        0.151188
# Alimentation osmoseur (L/j)               0.311267        0.423084
# Osmoseur (heures opération/j)             0.311254        0.423067
# Pression osmoseur (bar)                   0.051235       -0.034545
# Sucre sortie osmoseur (%)                 0.051235       -0.034545
# Température Bouilloire (0C)              -0.016665        0.035536
# Temps bouilloire (h)                      0.305330        0.401085
# Sucre du sirop obtenu (%)                -0.011889        0.032862
# Quantité de sirop obtenue (L)             0.312097        0.419702
# Transmittance produit (%)                -0.246508       -0.004325
# CategClasseSirop                          0.205487       -0.008151
#
#                                      Précip. tot. (mm)  \
# Année                                         0.068946
# Jour Calendrier Saison                        0.047551
# Temp max.(°C)                                 0.050561
# Temp min.(°C)                                 0.207606
# Temp moy.(°C)                                 0.140106
# Diff Temp (°C)                               -0.279098
# Précip. tot. (mm)                             1.000000
# Précip. Tot. Hiver (mm)                       0.089744
# Nombre épisodes gel/dégel                    -0.006516
# Production moyenne par entaille (L)           0.010370
# Débit sève (L/j)                             -0.138136
# Sucre sève (%)                               -0.720389
# Alimentation osmoseur (L/j)                  -0.138054
# Osmoseur (heures opération/j)                -0.138049
# Pression osmoseur (bar)                       0.009539
# Sucre sortie osmoseur (%)                     0.009539
# Température Bouilloire (0C)                  -0.019662
# Temps bouilloire (h)                         -0.125218
# Sucre du sirop obtenu (%)                    -0.022478
# Quantité de sirop obtenue (L)                -0.178476
# Transmittance produit (%)                    -0.016682
# CategClasseSirop                              0.018760
#
#                                      Précip. Tot. Hiver (mm)  \
# Année                                               0.770270
# Jour Calendrier Saison                             -0.108359
# Temp max.(°C)                                      -0.160530
# Temp min.(°C)                                      -0.211713
# Temp moy.(°C)                                      -0.196109
# Diff Temp (°C)                                      0.116612
# Précip. tot. (mm)                                   0.089744
# Précip. Tot. Hiver (mm)                             1.000000
# Nombre épisodes gel/dégel                          -0.111312
# Production moyenne par entaille (L)                 0.078374
# Débit sève (L/j)                                   -0.026494
# Sucre sève (%)                                     -0.316284
# Alimentation osmoseur (L/j)                        -0.034264
# Osmoseur (heures opération/j)                      -0.034263
# Pression osmoseur (bar)                            -0.025775
# Sucre sortie osmoseur (%)                          -0.025775
# Température Bouilloire (0C)                         0.017530
# Temps bouilloire (h)                               -0.022719
# Sucre du sirop obtenu (%)                           0.012517
# Quantité de sirop obtenue (L)                      -0.053081
# Transmittance produit (%)                           0.006463
# CategClasseSirop                                    0.001705
#
#                                      Nombre épisodes gel/dégel  \
# Année                                                 0.120394
# Jour Calendrier Saison                               -0.026489
# Temp max.(°C)                                         0.080940
# Temp min.(°C)                                         0.090037
# Temp moy.(°C)                                         0.089963
# Diff Temp (°C)                                       -0.029372
# Précip. tot. (mm)                                    -0.006516
# Précip. Tot. Hiver (mm)                              -0.111312
# Nombre épisodes gel/dégel                             1.000000
# Production moyenne par entaille (L)                   0.953702
# Débit sève (L/j)                                      0.235871
# Sucre sève (%)                                        0.641598
# Alimentation osmoseur (L/j)                           0.236107
# Osmoseur (heures opération/j)                         0.236125
# Pression osmoseur (bar)                              -0.047123
# Sucre sortie osmoseur (%)                            -0.047123
# Température Bouilloire (0C)                           0.019937
# Temps bouilloire (h)                                  0.243651
# Sucre du sirop obtenu (%)                             0.016306
# Quantité de sirop obtenue (L)                         0.297288
# Transmittance produit (%)                             0.054258
# CategClasseSirop                                     -0.038570
#
#                                      Production moyenne par entaille (L)  ...  \
# Année                                                           0.292406  ...
# Jour Calendrier Saison                                         -0.043370  ...
# Temp max.(°C)                                                   0.058584  ...
# Temp min.(°C)                                                   0.056036  ...
# Temp moy.(°C)                                                   0.060362  ...
# Diff Temp (°C)                                                 -0.004684  ...
# Précip. tot. (mm)                                               0.010370  ...
# Précip. Tot. Hiver (mm)                                         0.078374  ...
# Nombre épisodes gel/dégel                                       0.953702  ...
# Production moyenne par entaille (L)                             1.000000  ...
# Débit sève (L/j)                                                0.238466  ...
# Sucre sève (%)                                                  0.566372  ...
# Alimentation osmoseur (L/j)                                     0.235615  ...
# Osmoseur (heures opération/j)                                   0.235632  ...
# Pression osmoseur (bar)                                        -0.047492  ...
# Sucre sortie osmoseur (%)                                      -0.047492  ...
# Température Bouilloire (0C)                                     0.027756  ...
# Temps bouilloire (h)                                            0.246391  ...
# Sucre du sirop obtenu (%)                                       0.024188  ...
# Quantité de sirop obtenue (L)                                   0.290231  ...
# Transmittance produit (%)                                       0.055052  ...
# CategClasseSirop                                               -0.040242  ...
#
#                                      Alimentation osmoseur (L/j)  \
# Année                                                   0.039093
# Jour Calendrier Saison                                  0.280341
# Temp max.(°C)                                           0.448579
# Temp min.(°C)                                           0.159015
# Temp moy.(°C)                                           0.311267
# Diff Temp (°C)                                          0.423084
# Précip. tot. (mm)                                      -0.138054
# Précip. Tot. Hiver (mm)                                -0.034264
# Nombre épisodes gel/dégel                               0.236107
# Production moyenne par entaille (L)                     0.235615
# Débit sève (L/j)                                        0.964245
# Sucre sève (%)                                          0.241627
# Alimentation osmoseur (L/j)                             1.000000
# Osmoseur (heures opération/j)                           1.000000
# Pression osmoseur (bar)                                -0.006666
# Sucre sortie osmoseur (%)                              -0.006666
# Température Bouilloire (0C)                            -0.012458
# Temps bouilloire (h)                                    0.907063
# Sucre du sirop obtenu (%)                              -0.012196
# Quantité de sirop obtenue (L)                           0.954982
# Transmittance produit (%)                               0.037089
# CategClasseSirop                                       -0.021089
#
#                                      Osmoseur (heures opération/j)  \
# Année                                                     0.039085
# Jour Calendrier Saison                                    0.280338
# Temp max.(°C)                                             0.448560
# Temp min.(°C)                                             0.159008
# Temp moy.(°C)                                             0.311254
# Diff Temp (°C)                                            0.423067
# Précip. tot. (mm)                                        -0.138049
# Précip. Tot. Hiver (mm)                                  -0.034263
# Nombre épisodes gel/dégel                                 0.236125
# Production moyenne par entaille (L)                       0.235632
# Débit sève (L/j)                                          0.964236
# Sucre sève (%)                                            0.241630
# Alimentation osmoseur (L/j)                               1.000000
# Osmoseur (heures opération/j)                             1.000000
# Pression osmoseur (bar)                                  -0.006674
# Sucre sortie osmoseur (%)                                -0.006674
# Température Bouilloire (0C)                              -0.012459
# Temps bouilloire (h)                                      0.907045
# Sucre du sirop obtenu (%)                                -0.012195
# Quantité de sirop obtenue (L)                             0.954974
# Transmittance produit (%)                                 0.037123
# CategClasseSirop                                         -0.021092
#
#                                      Pression osmoseur (bar)  \
# Année                                              -0.008857
# Jour Calendrier Saison                              0.050691
# Temp max.(°C)                                       0.039888
# Temp min.(°C)                                       0.056696
# Temp moy.(°C)                                       0.051235
# Diff Temp (°C)                                     -0.034545
# Précip. tot. (mm)                                   0.009539
# Précip. Tot. Hiver (mm)                            -0.025775
# Nombre épisodes gel/dégel                          -0.047123
# Production moyenne par entaille (L)                -0.047492
# Débit sève (L/j)                                   -0.002051
# Sucre sève (%)                                     -0.028486
# Alimentation osmoseur (L/j)                        -0.006666
# Osmoseur (heures opération/j)                      -0.006674
# Pression osmoseur (bar)                             1.000000
# Sucre sortie osmoseur (%)                           1.000000
# Température Bouilloire (0C)                        -0.016548
# Temps bouilloire (h)                               -0.034077
# Sucre du sirop obtenu (%)                          -0.017561
# Quantité de sirop obtenue (L)                      -0.002381
# Transmittance produit (%)                          -0.017204
# CategClasseSirop                                    0.010971
#
#                                      Sucre sortie osmoseur (%)  \
# Année                                                -0.008857
# Jour Calendrier Saison                                0.050691
# Temp max.(°C)                                         0.039888
# Temp min.(°C)                                         0.056696
# Temp moy.(°C)                                         0.051235
# Diff Temp (°C)                                       -0.034545
# Précip. tot. (mm)                                     0.009539
# Précip. Tot. Hiver (mm)                              -0.025775
# Nombre épisodes gel/dégel                            -0.047123
# Production moyenne par entaille (L)                  -0.047492
# Débit sève (L/j)                                     -0.002051
# Sucre sève (%)                                       -0.028486
# Alimentation osmoseur (L/j)                          -0.006666
# Osmoseur (heures opération/j)                        -0.006674
# Pression osmoseur (bar)                               1.000000
# Sucre sortie osmoseur (%)                             1.000000
# Température Bouilloire (0C)                          -0.016548
# Temps bouilloire (h)                                 -0.034077
# Sucre du sirop obtenu (%)                            -0.017561
# Quantité de sirop obtenue (L)                        -0.002381
# Transmittance produit (%)                            -0.017204
# CategClasseSirop                                      0.010971
#
#                                      Température Bouilloire (0C)  \
# Année                                                   0.029629
# Jour Calendrier Saison                                 -0.045762
# Temp max.(°C)                                          -0.005782
# Temp min.(°C)                                          -0.025731
# Temp moy.(°C)                                          -0.016665
# Diff Temp (°C)                                          0.035536
# Précip. tot. (mm)                                      -0.019662
# Précip. Tot. Hiver (mm)                                 0.017530
# Nombre épisodes gel/dégel                               0.019937
# Production moyenne par entaille (L)                     0.027756
# Débit sève (L/j)                                       -0.011851
# Sucre sève (%)                                          0.013664
# Alimentation osmoseur (L/j)                            -0.012458
# Osmoseur (heures opération/j)                          -0.012459
# Pression osmoseur (bar)                                -0.016548
# Sucre sortie osmoseur (%)                              -0.016548
# Température Bouilloire (0C)                             1.000000
# Temps bouilloire (h)                                   -0.008792
# Sucre du sirop obtenu (%)                               0.990001
# Quantité de sirop obtenue (L)                          -0.021910
# Transmittance produit (%)                               0.010046
# CategClasseSirop                                       -0.031692
#
#                                      Temps bouilloire (h)  \
# Année                                            0.051315
# Jour Calendrier Saison                           0.274606
# Temp max.(°C)                                    0.435913
# Temp min.(°C)                                    0.160151
# Temp moy.(°C)                                    0.305330
# Diff Temp (°C)                                   0.401085
# Précip. tot. (mm)                               -0.125218
# Précip. Tot. Hiver (mm)                         -0.022719
# Nombre épisodes gel/dégel                        0.243651
# Production moyenne par entaille (L)              0.246391
# Débit sève (L/j)                                 0.970952
# Sucre sève (%)                                   0.240365
# Alimentation osmoseur (L/j)                      0.907063
# Osmoseur (heures opération/j)                    0.907045
# Pression osmoseur (bar)                         -0.034077
# Sucre sortie osmoseur (%)                       -0.034077
# Température Bouilloire (0C)                     -0.008792
# Temps bouilloire (h)                             1.000000
# Sucre du sirop obtenu (%)                       -0.009440
# Quantité de sirop obtenue (L)                    0.970807
# Transmittance produit (%)                       -0.144637
# CategClasseSirop                                 0.122140
#
#                                      Sucre du sirop obtenu (%)  \
# Année                                                 0.027543
# Jour Calendrier Saison                               -0.038425
# Temp max.(°C)                                        -0.001757
# Temp min.(°C)                                        -0.020595
# Temp moy.(°C)                                        -0.011889
# Diff Temp (°C)                                        0.032862
# Précip. tot. (mm)                                    -0.022478
# Précip. Tot. Hiver (mm)                               0.012517
# Nombre épisodes gel/dégel                             0.016306
# Production moyenne par entaille (L)                   0.024188
# Débit sève (L/j)                                     -0.011334
# Sucre sève (%)                                        0.013543
# Alimentation osmoseur (L/j)                          -0.012196
# Osmoseur (heures opération/j)                        -0.012195
# Pression osmoseur (bar)                              -0.017561
# Sucre sortie osmoseur (%)                            -0.017561
# Température Bouilloire (0C)                           0.990001
# Temps bouilloire (h)                                 -0.009440
# Sucre du sirop obtenu (%)                             1.000000
# Quantité de sirop obtenue (L)                        -0.021766
# Transmittance produit (%)                             0.002210
# CategClasseSirop                                     -0.025467
#
#                                      Quantité de sirop obtenue (L)  \
# Année                                                     0.041213
# Jour Calendrier Saison                                    0.281603
# Temp max.(°C)                                             0.448399
# Temp min.(°C)                                             0.160767
# Temp moy.(°C)                                             0.312097
# Diff Temp (°C)                                            0.419702
# Précip. tot. (mm)                                        -0.178476
# Précip. Tot. Hiver (mm)                                  -0.053081
# Nombre épisodes gel/dégel                                 0.297288
# Production moyenne par entaille (L)                       0.290231
# Débit sève (L/j)                                          0.987074
# Sucre sève (%)                                            0.317804
# Alimentation osmoseur (L/j)                               0.954982
# Osmoseur (heures opération/j)                             0.954974
# Pression osmoseur (bar)                                  -0.002381
# Sucre sortie osmoseur (%)                                -0.002381
# Température Bouilloire (0C)                              -0.021910
# Temps bouilloire (h)                                      0.970807
# Sucre du sirop obtenu (%)                                -0.021766
# Quantité de sirop obtenue (L)                             1.000000
# Transmittance produit (%)                                -0.092841
# CategClasseSirop                                          0.082229
#
#                                      Transmittance produit (%)  \
# Année                                                 0.031924
# Jour Calendrier Saison                               -0.337132
# Temp max.(°C)                                        -0.249899
# Temp min.(°C)                                        -0.222120
# Temp moy.(°C)                                        -0.246508
# Diff Temp (°C)                                       -0.004325
# Précip. tot. (mm)                                    -0.016682
# Précip. Tot. Hiver (mm)                               0.006463
# Nombre épisodes gel/dégel                             0.054258
# Production moyenne par entaille (L)                   0.055052
# Débit sève (L/j)                                     -0.100306
# Sucre sève (%)                                        0.045541
# Alimentation osmoseur (L/j)                           0.037089
# Osmoseur (heures opération/j)                         0.037123
# Pression osmoseur (bar)                              -0.017204
# Sucre sortie osmoseur (%)                            -0.017204
# Température Bouilloire (0C)                           0.010046
# Temps bouilloire (h)                                 -0.144637
# Sucre du sirop obtenu (%)                             0.002210
# Quantité de sirop obtenue (L)                        -0.092841
# Transmittance produit (%)                             1.000000
# CategClasseSirop                                     -0.809605
#
#                                      CategClasseSirop
# Année                                       -0.017023
# Jour Calendrier Saison                       0.283606
# Temp max.(°C)                                0.204277
# Temp min.(°C)                                0.188086
# Temp moy.(°C)                                0.205487
# Diff Temp (°C)                              -0.008151
# Précip. tot. (mm)                            0.018760
# Précip. Tot. Hiver (mm)                      0.001705
# Nombre épisodes gel/dégel                   -0.038570
# Production moyenne par entaille (L)         -0.040242
# Débit sève (L/j)                             0.088368
# Sucre sève (%)                              -0.038644
# Alimentation osmoseur (L/j)                 -0.021089
# Osmoseur (heures opération/j)               -0.021092
# Pression osmoseur (bar)                      0.010971
# Sucre sortie osmoseur (%)                    0.010971
# Température Bouilloire (0C)                 -0.031692
# Temps bouilloire (h)                         0.122140
# Sucre du sirop obtenu (%)                   -0.025467
# Quantité de sirop obtenue (L)                0.082229
# Transmittance produit (%)                   -0.809605
# CategClasseSirop                             1.000000
#
# [22 rows x 22 columns]

# %%
sorted_pairs = corr.unstack().sort_values(kind="quicksort", ascending=False).dropna()
len(sorted_pairs)
# Out:
# 484

# %%
x = sorted_pairs.where(sorted_pairs <1)

# %%
type(corr.unstack())
# Out:
# pandas.core.series.Series

# %%
#sns.heatmap(corr, cbar=True, center=0, annot=True, fmt="0.2f", cmap="Blues")

# %% [markdown]
# ### apply model and check. Then, cut out variables

# %%
## seulement les variables X
dfNumerique_X_cols = dfNumerique.loc[:, ~dfNumerique.columns.isin(list_cols_dependennt_vars)].copy()

## seulement les variables Y
dfNumerique_Y_cols = dfNumerique.loc[:, dfNumerique.columns.isin(list_cols_dependennt_vars)].copy()

len(dfNumerique.columns)
# Out:
# 22

# %%
### vif
## https://www.kdnuggets.com/2019/07/check-quality-regression-model-python.html
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

# %%
### https://www.geeksforgeeks.org/detecting-multicollinearity-with-vif-python/

# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = dfNumerique_X_cols.columns

# %%
len(dfNumerique_X_cols.columns)
# Out:
# 18

# %%
len([vif(dfNumerique_X_cols.values, i)for i in range(len(dfNumerique_X_cols.columns))])
# Out:
# 18

# %%
# calculating VIF for each feature

vif_data["VIF"] = [vif(dfNumerique_X_cols.values, i)
                          for i in range(len(dfNumerique_X_cols.columns))]

vif_data.sort_values(by="VIF", axis=0, kind="quicksort",  ascending=False)
# Out:
#                           feature           VIF
# 11        Pression osmoseur (bar)  1.629840e+07
# 9     Alimentation osmoseur (L/j)  2.044157e+06
# 10  Osmoseur (heures opération/j)  2.043838e+06
# 12      Sucre sortie osmoseur (%)  6.964214e+05
# 4                   Temp moy.(°C)  3.432822e+03
# 3                   Temp min.(°C)  2.345469e+03
# 2                   Temp max.(°C)  1.519696e+03
# 5                  Diff Temp (°C)  3.580033e+02
# 16  Quantité de sirop obtenue (L)  5.217874e+01
# 13    Température Bouilloire (0C)  5.075661e+01
# 15      Sucre du sirop obtenu (%)  5.068031e+01
# 14           Temps bouilloire (h)  2.317438e+01
# 7         Précip. Tot. Hiver (mm)  2.860497e+00
# 0                           Année  2.803114e+00
# 1          Jour Calendrier Saison  2.414470e+00
# 8       Nombre épisodes gel/dégel  1.447611e+00
# 17               CategClasseSirop  1.281434e+00
# 6               Précip. tot. (mm)  1.251522e+00

# %%
dfVifPlusGrand10 = vif_data[vif_data["VIF"] >10]
len(dfVifPlusGrand10)
# Out:
# 12

# %%
#type(dfVifPlusGrand10.columns.values.tolist())
#type(list_cols_dependennt_vars)
# Out:
# list

# %%
### dfNumerique_X sans les vif >10
dfNumerique_X_cols_vif =[]
dfNumerique_X_cols_vif = dfNumerique_X_cols.loc[:, ~dfNumerique_X_cols.columns.isin(dfVifPlusGrand10["feature"].values)].copy()
#for x in (dfVifPlusGrand10["feature"].values):
#    print("col: ", x)
len(dfNumerique_X_cols_vif.columns)
# Out:
# filho da puta:  Temp max.(°C)
# filho da puta:  Temp min.(°C)
# filho da puta:  Temp moy.(°C)
# filho da puta:  Diff Temp (°C)
# filho da puta:  Alimentation osmoseur (L/j)
# filho da puta:  Osmoseur (heures opération/j)
# filho da puta:  Pression osmoseur (bar)
# filho da puta:  Sucre sortie osmoseur (%)
# filho da puta:  Température Bouilloire (0C)
# filho da puta:  Temps bouilloire (h)
# filho da puta:  Sucre du sirop obtenu (%)
# filho da puta:  Quantité de sirop obtenue (L)
# 6

# %% [markdown]
# ######

# %%
## On voit qu'il y a certaines correlations parfaites
## ex: (temp moyen, temp max), (temp moyen, temp min), (moyenne entaille, episode gel/degel)
## (pression osmoseur bar, boullioire 0c), (pression osmoseur bar, quantité sirop obtenu %)
## (osmoseur heures opération, alimentation osmoseur (L/j))
## (Sucre sortie osmoseur (%), pression osmoseur)
## (alimentation osmoseur, (L/j), temps boulloire) -> 0.89
## (débit sève, heures opération/j)
## Enlevons quelques unes de ces variables et revoyons la correlation
list_col_redondantes = ['Temp min.(°C)', 'Temp max.(°C)', 'Température Bouilloire (0C)'
                       , 'Quantité de sirop obtenue (L)', 'Sucre du sirop obtenu (%)'
                       , 'Osmoseur (heures opération/j)', 'Sucre sortie osmoseur (%)'
                       , 'Temps bouilloire (h)'
                       ]

## On repète l'opération antérieur avec moins de colonnes
dfNumerique = dfNumerique.loc[:, ~dfNumerique.columns.isin(list_col_redondantes)]

corr = dfNumerique.corr()

## heatmap sans correlations parfaites ou presque parfaite:
sns.heatmap(corr, cbar=True, cmap="Blues", center=0, annot=True, fmt=".2f")
# Out:
# <AxesSubplot: >

# %%
### pandas.series condition https://www.youtube.com/watch?v=BgfvF6mu20c
### pour chaque var Y, imprimer les variables les plus correlées
### on applique la condition 
for col in list_cols_dependennt_vars:
    print("===========================")
    print(" y = ", col.name)
    cond_correl_plus_grand_50 = ((corr[col.name] > 0.5) & (corr[col.name] <1)) 
    print(corr[col.name][cond_correl_plus_grand_50].sort_values(ascending=False))
    
#list_cols_dependennt_vars
# Out:
# ===========================
#  y =  Débit sève (L/j)
# Alimentation osmoseur (L/j)    0.966506
# Name: Débit sève (L/j), dtype: float64
# ===========================
#  y =  Sucre sève (%)
# Pression osmoseur (bar)      0.903895
# Transmittance produit (%)    0.760474
# CategClasseSirop             0.639687
# Name: Sucre sève (%), dtype: float64
# ===========================
#  y =  Transmittance produit (%)
# Pression osmoseur (bar)    0.813070
# Sucre sève (%)             0.760474
# Name: Transmittance produit (%), dtype: float64
# ===========================
#  y =  Production moyenne par entaille (L)
# Nombre épisodes gel/dégel    0.952072
# Name: Production moyenne par entaille (L), dtype: float64

# %%
sns.pairplot(dfNumerique)

# %% [markdown]
# ### At this point, we have strong relationships:
# - Débit sève (L/j) --> Alimentation osmoseur (L/j) [0.97]
# - Sucre sève (%) --> Pression osmoseur (bar) [0.9]
# - Transmittance produit (%) --> Pression osmoseur (bar)[0.81], Sucre sortie osmoseur (%) [0.68]
# - Production moyenne par entaille (L) --> Nombre épisodes gel/dégel [0.95]

# %%
## Transmitance
### pression_osmoseur_vs_transmittance
sns.lmplot(x='Pression osmoseur (bar)', y = 'Transmittance produit (%)', data = dfNumerique)

# %%
## Le graphique ression_osmoseur_vs_transmittance montre une concentration
## dans x près de 40. Regardons s'il y a des outliers:
sns.boxplot(x='Pression osmoseur (bar)',data = dfNumerique)

# %%
## effectivement, le boxplot nous montre la présence des outliers
stats = dfNumerique['Pression osmoseur (bar)'].describe()
stats

# %%
sns.lmplot(x='Alimentation osmoseur (L/j)' , y='Débit sève (L/j)', data=dfNumerique)

# %%
### regardons combien de 0:
sns.histplot(x='Pression osmoseur (bar)',data = dfNumerique)

# %%
#sns.pairplot(dfNumerique)

# %%
## correlation seulement entre les variables indépendantes

dfDependantVars= dfNumerique.loc[:, ~dfNumerique.columns.isin([col.name for col in list_cols_dependennt_vars])]
type(dfDependantVars)

corr2 = dfDependantVars.corr()
sns.heatmap(corr2, cbar=True, annot=True, cmap="Blues", fmt=".02f", center=0)

# %% [markdown]
# Multiple Linear Regression - https://www.youtube.com/watch?v=J_LnPL3Qg70

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()

## https://www.statology.org/pandas-exclude-column/
#select all columns except 'rebounds' and 'assists'
#df.loc[:, ~df.columns.isin(['rebounds', 'assists'])]
list_reg = []
for col in list_cols_dependennt_vars:
 #   print(col.name)
    #result = reg.fit(dfNumerique[:, ~dfNumerique.columns.isin([col.name for col in list_cols_dependennt_vars])], dfNumerique[col.name])
    result = reg.fit(dfNumerique.loc[:, ~dfNumerique.columns.isin([col.name for col in list_cols_dependennt_vars])], dfNumerique[col.name])
    list_reg.append(result)


#dfNumerique['Année'].name
#list_cols_dependennt_vars[0].name
#[col.name for col in list_cols_dependennt_vars]
#reg.fit(dfNumerique.loc[:, ~dfNumerique.columns.isin([col.name for col in list_cols_dependennt_vars])], dfNumerique['Débit sève (L/j)'])
#type(dfNumerique.loc[:, ~dfNumerique.columns.isin([col.name for col in list_cols_dependennt_vars])])
#dfNumeriqueIndepVar = dfNumerique[:, ~dfNumerique.columns.isin([col.name for col in list_cols_dependennt_vars])]

# %%
print("coefs: ", list_reg[0].coef_.round(2))
print("intercept: ", list_reg[0].intercept_)

# %% [markdown]
# fonction vérif distr normale

# %%
def print_dist_norm(pCol, pXlabel, pYlabel="Fonction de densité f(x)", pNbRuns=1000):
    grille_x = np.linspace(pCol.min(), pCol.max(), pNbRuns)
    dx=(pCol.max()-(pCol.min()))/(pNbRuns-1)
    mu, sigma = sts.norm.fit(pCol.values)
    param=sts.norm.fit(pCol.values)
    pdf = sts.norm.pdf(grille_x, mu, sigma)
    ax=pCol.plot.hist(density=True, bins = 10, color = 'blue', edgecolor = 'black')
    ax.set_xlabel(pXlabel)
    ax.plot(grille_x, pdf, linewidth=3, color = 'red')
    ax.set_ylabel(pYlabel)
