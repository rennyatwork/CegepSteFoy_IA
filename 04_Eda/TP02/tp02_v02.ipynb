# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import statsmodels.api as stm
import statsmodels.stats.weightstats as ws
import math
import seaborn as sns
import os

# %%
# %matplotlib
# Out:
# Using matplotlib backend: GTK3Agg

# %%
os
# Out:
# <module 'os' from '/usr/lib/python3.8/os.py'>

# %%
print (os.getcwd())
currDir = os.getcwd()
fullPath = currDir + "/CabaneASucrev0r3.csv"
type(currDir)
# Out:
# /home/hadoop/Git_Ia/CegepSteFoy_IA/04_Eda/TP02
# str

# %%
donnee = pd.read_csv(fullPath)
stats=donnee.describe()
dimensions=donnee.shape
stats
# Out:
#              Année  Jour Calendrier Saison  Temp max.(°C)  Temp min.(°C)  \
# count  1875.000000             1875.000000     1873.00000    1875.000000
# mean   2010.000000               45.144000        1.51543      -8.633867
# std       6.059559               25.781811        7.63530       8.695859
# min    2000.000000                1.000000      -22.60000     -34.800000
# 25%    2005.000000               23.000000       -3.60000     -15.100000
# 50%    2010.000000               45.000000        1.70000      -6.700000
# 75%    2015.000000               67.000000        6.40000      -1.450000
# max    2020.000000               90.000000       27.50000      10.000000
#
#        Temp moy.(°C)  Diff Temp (°C)  Précip. tot. (mm)  \
# count    1873.000000     1875.000000        1872.000000
# mean       -3.557768       10.147680           2.738568
# std         7.843854        4.770659           5.574896
# min       -25.700000        0.900000           0.000000
# 25%        -9.300000        6.700000           0.000000
# 50%        -2.500000        9.600000           0.000000
# 75%         2.400000       13.100000           2.600000
# max        18.800000       31.000000          41.600000
#
#        Précip. Tot. Hiver (mm)  Nombre épisodes gel/dégel  \
# count              1875.000000                1875.000000
# mean                610.334347                  20.633067
# std                 126.965290                   5.251394
# min                 313.200000                  14.000000
# 25%                 536.400000                  16.000000
# 50%                 620.300000                  20.000000
# 75%                 685.100000                  25.000000
# max                 811.700000                  30.000000
#
#        Production moyenne par entaille (L)  ...     Pixel6_B     Pixel7_R  \
# count                          1875.000000  ...  1875.000000  1875.000000
# mean                             26.523733  ...    33.771435   157.936992
# std                              10.234991  ...    26.416038    85.971146
# min                              11.567238  ...     0.000000     0.000000
# 25%                              17.280176  ...     8.345000   111.895000
# 50%                              26.462002  ...    32.970000   183.190000
# 75%                              34.315361  ...    55.820000   227.420000
# max                              46.784424  ...   108.800000   255.000000
#
#           Pixel7_G     Pixel7_B     Pixel8_R     Pixel8_G     Pixel8_B  \
# count  1875.000000  1875.000000  1875.000000  1875.000000  1875.000000
# mean     71.317269    32.709104   156.869221    70.605899    33.460053
# std      52.296358    26.692262    85.231625    52.970868    27.297388
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      32.555000     4.865000   111.960000    31.290000     5.545000
# 50%      71.920000    31.110000   180.810000    69.960000    31.410000
# 75%     102.465000    54.910000   224.955000   103.015000    56.400000
# max     255.000000   125.400000   255.000000   255.000000   117.940000
#
#           Pixel9_R     Pixel9_G     Pixel9_B
# count  1875.000000  1875.000000  1875.000000
# mean    157.787557    70.609437    32.820418
# std      85.760582    53.761268    27.040843
# min       0.000000     0.000000     0.000000
# 25%     109.940000    28.830373     4.326591
# 50%     183.020000    70.558732    31.111611
# 75%     225.820000   104.848430    55.027608
# max     255.000000   255.000000   132.121595
#
# [8 rows x 48 columns]

# %%
donnee.isnull().sum()
# Out:
# Date                                   0
# Année                                  0
# Jour Calendrier Saison                 0
# Temp max.(°C)                          2
# Temp min.(°C)                          0
# Temp moy.(°C)                          2
# Diff Temp (°C)                         0
# Précip. tot. (mm)                      3
# Précip. Tot. Hiver (mm)                0
# Nombre épisodes gel/dégel              0
# Production moyenne par entaille (L)    0
# Débit sève (L/j)                       0
# Sucre sève (%)                         0
# Alimentation osmoseur (L/j)            0
# Osmoseur (heures opération/j)          0
# Pression osmoseur (bar)                0
# Sucre sortie osmoseur (%)              0
# Température Bouilloire (0C)            0
# Temps bouilloire (h)                   0
# Sucre du sirop obtenu (%)              0
# Quantité de sirop obtenue (L)          0
# Transmittance produit (%)              0
# Pixel1_R                               0
# Pixel1_G                               0
# Pixel1_B                               0
# Pixel2_R                               0
# Pixel2_G                               0
# Pixel2_B                               0
# Pixel3_R                               0
# Pixel3_G                               0
# Pixel3_B                               0
# Pixel4_R                               0
# Pixel4_G                               0
# Pixel4_B                               0
# Pixel5_R                               0
# Pixel5_G                               0
# Pixel5_B                               0
# Pixel6_R                               0
# Pixel6_G                               0
# Pixel6_B                               0
# Pixel7_R                               0
# Pixel7_G                               0
# Pixel7_B                               0
# Pixel8_R                               0
# Pixel8_G                               0
# Pixel8_B                               0
# Pixel9_R                               0
# Pixel9_G                               0
# Pixel9_B                               0
# Classe Sirop                           0
# dtype: int64

# %% [markdown]
# Heureusement, très peu de nulls

# %% [markdown]
# Quels sont les enregistrements contenant des nulls?

# %%
donnee[(donnee['Temp max.(°C)'].isna()==True) | (donnee['Précip. tot. (mm)'].isna()==True)]
# Out:
#             Date  Année  Jour Calendrier Saison  Temp max.(°C)  Temp min.(°C)  \
# 1519  2017-02-02   2017                       2            NaN          -17.4
# 1524  2017-02-07   2017                       7            NaN          -25.1
# 1632  2018-02-26   2018                      26            3.2           -7.4
#
#       Temp moy.(°C)  Diff Temp (°C)  Précip. tot. (mm)  \
# 1519            NaN            17.4                NaN
# 1524            NaN            25.1                NaN
# 1632           -2.1            10.6                NaN
#
#       Précip. Tot. Hiver (mm)  Nombre épisodes gel/dégel  ...  Pixel7_R  \
# 1519                    770.6                         20  ...    224.35
# 1524                    770.6                         20  ...    255.00
# 1632                    811.7                         16  ...    213.40
#
#       Pixel7_G  Pixel7_B  Pixel8_R  Pixel8_G  Pixel8_B  Pixel9_R    Pixel9_G  \
# 1519    173.08     30.45    255.00    127.83     77.18    255.00  127.017170
# 1524    131.77      3.27    225.25    123.51     61.07    194.07   70.795317
# 1632    111.76      3.39    212.26     98.49     35.60    193.85  127.018875
#
#        Pixel9_B  Classe Sirop
# 1519  10.139073         Ambré
# 1524  71.603721         Foncé
# 1632  37.339503         Foncé
#
# [3 rows x 50 columns]

# %% [markdown]
# Fill le NA et obtient un dataframe sans null

# %%
donnee.fillna(method='bfill', inplace=True)
donnee.isnull().sum()
# Out:
# Date                                   0
# Année                                  0
# Jour Calendrier Saison                 0
# Temp max.(°C)                          0
# Temp min.(°C)                          0
# Temp moy.(°C)                          0
# Diff Temp (°C)                         0
# Précip. tot. (mm)                      0
# Précip. Tot. Hiver (mm)                0
# Nombre épisodes gel/dégel              0
# Production moyenne par entaille (L)    0
# Débit sève (L/j)                       0
# Sucre sève (%)                         0
# Alimentation osmoseur (L/j)            0
# Osmoseur (heures opération/j)          0
# Pression osmoseur (bar)                0
# Sucre sortie osmoseur (%)              0
# Température Bouilloire (0C)            0
# Temps bouilloire (h)                   0
# Sucre du sirop obtenu (%)              0
# Quantité de sirop obtenue (L)          0
# Transmittance produit (%)              0
# Pixel1_R                               0
# Pixel1_G                               0
# Pixel1_B                               0
# Pixel2_R                               0
# Pixel2_G                               0
# Pixel2_B                               0
# Pixel3_R                               0
# Pixel3_G                               0
# Pixel3_B                               0
# Pixel4_R                               0
# Pixel4_G                               0
# Pixel4_B                               0
# Pixel5_R                               0
# Pixel5_G                               0
# Pixel5_B                               0
# Pixel6_R                               0
# Pixel6_G                               0
# Pixel6_B                               0
# Pixel7_R                               0
# Pixel7_G                               0
# Pixel7_B                               0
# Pixel8_R                               0
# Pixel8_G                               0
# Pixel8_B                               0
# Pixel9_R                               0
# Pixel9_G                               0
# Pixel9_B                               0
# Classe Sirop                           0
# dtype: int64

# %%
donnee.columns
# Out:
# Index(['Date', 'Année', 'Jour Calendrier Saison', 'Temp max.(°C)',
#        'Temp min.(°C)', 'Temp moy.(°C)', 'Diff Temp (°C)', 'Précip. tot. (mm)',
#        'Précip. Tot. Hiver (mm)', 'Nombre épisodes gel/dégel',
#        'Production moyenne par entaille (L)', 'Débit sève (L/j)',
#        'Sucre sève (%)', 'Alimentation osmoseur (L/j)',
#        'Osmoseur (heures opération/j)', 'Pression osmoseur (bar)',
#        'Sucre sortie osmoseur (%)', 'Température Bouilloire (0C)',
#        'Temps bouilloire (h)', 'Sucre du sirop obtenu (%)',
#        'Quantité de sirop obtenue (L)', 'Transmittance produit (%)',
#        'Pixel1_R', 'Pixel1_G', 'Pixel1_B', 'Pixel2_R', 'Pixel2_G', 'Pixel2_B',
#        'Pixel3_R', 'Pixel3_G', 'Pixel3_B', 'Pixel4_R', 'Pixel4_G', 'Pixel4_B',
#        'Pixel5_R', 'Pixel5_G', 'Pixel5_B', 'Pixel6_R', 'Pixel6_G', 'Pixel6_B',
#        'Pixel7_R', 'Pixel7_G', 'Pixel7_B', 'Pixel8_R', 'Pixel8_G', 'Pixel8_B',
#        'Pixel9_R', 'Pixel9_G', 'Pixel9_B', 'Classe Sirop'],
#       dtype='object')

# %% [markdown]
# Exclure Pixel columns

# %%
donnee.filter(like='Pixel').columns
dfSansPixel = donnee.drop(donnee.filter(like='Pixel').columns, axis=1)
dfSansPixel.columns
# Out:
# Index(['Date', 'Année', 'Jour Calendrier Saison', 'Temp max.(°C)',
#        'Temp min.(°C)', 'Temp moy.(°C)', 'Diff Temp (°C)', 'Précip. tot. (mm)',
#        'Précip. Tot. Hiver (mm)', 'Nombre épisodes gel/dégel',
#        'Production moyenne par entaille (L)', 'Débit sève (L/j)',
#        'Sucre sève (%)', 'Alimentation osmoseur (L/j)',
#        'Osmoseur (heures opération/j)', 'Pression osmoseur (bar)',
#        'Sucre sortie osmoseur (%)', 'Température Bouilloire (0C)',
#        'Temps bouilloire (h)', 'Sucre du sirop obtenu (%)',
#        'Quantité de sirop obtenue (L)', 'Transmittance produit (%)',
#        'Classe Sirop'],
#       dtype='object')

# %%
dfSansPixel.dtypes
# Out:
# Date                                    object
# Année                                    int64
# Jour Calendrier Saison                   int64
# Temp max.(°C)                          float64
# Temp min.(°C)                          float64
# Temp moy.(°C)                          float64
# Diff Temp (°C)                         float64
# Précip. tot. (mm)                      float64
# Précip. Tot. Hiver (mm)                float64
# Nombre épisodes gel/dégel                int64
# Production moyenne par entaille (L)    float64
# Débit sève (L/j)                       float64
# Sucre sève (%)                         float64
# Alimentation osmoseur (L/j)            float64
# Osmoseur (heures opération/j)          float64
# Pression osmoseur (bar)                float64
# Sucre sortie osmoseur (%)              float64
# Température Bouilloire (0C)            float64
# Temps bouilloire (h)                   float64
# Sucre du sirop obtenu (%)                int64
# Quantité de sirop obtenue (L)          float64
# Transmittance produit (%)              float64
# Classe Sirop                            object
# dtype: object

# %%
dfSansPixel.tail(10)
# Out:
#             Date  Année  Jour Calendrier Saison  Temp max.(°C)  Temp min.(°C)  \
# 1865  2020-04-21   2020                      81            7.1           -5.9
# 1866  2020-04-22   2020                      82           -0.3           -5.4
# 1867  2020-04-23   2020                      83            5.7           -6.6
# 1868  2020-04-24   2020                      84           10.5           -7.4
# 1869  2020-04-25   2020                      85           12.7           -4.8
# 1870  2020-04-26   2020                      86           12.5           -2.3
# 1871  2020-04-27   2020                      87           10.1            2.9
# 1872  2020-04-28   2020                      88           12.1           -0.8
# 1873  2020-04-29   2020                      89           15.3           -1.5
# 1874  2020-04-30   2020                      90            7.1            5.6
#
#       Temp moy.(°C)  Diff Temp (°C)  Précip. tot. (mm)  \
# 1865            0.6            13.0                4.7
# 1866           -2.8             5.1                0.0
# 1867           -0.4            12.3                0.0
# 1868            1.6            17.9                0.0
# 1869            3.9            17.5                0.0
# 1870            5.1            14.8                0.0
# 1871            6.5             7.2                0.0
# 1872            5.6            12.9                0.0
# 1873            6.9            16.8                0.0
# 1874            6.4             1.5               12.0
#
#       Précip. Tot. Hiver (mm)  Nombre épisodes gel/dégel  ...  \
# 1865                    688.3                         30  ...
# 1866                    688.3                         30  ...
# 1867                    688.3                         30  ...
# 1868                    688.3                         30  ...
# 1869                    688.3                         30  ...
# 1870                    688.3                         30  ...
# 1871                    688.3                         30  ...
# 1872                    688.3                         30  ...
# 1873                    688.3                         30  ...
# 1874                    688.3                         30  ...
#
#       Alimentation osmoseur (L/j)  Osmoseur (heures opération/j)  \
# 1865                       5352.0                          12.04
# 1866                        218.0                           0.49
# 1867                       4030.0                           9.07
# 1868                       7177.0                          16.15
# 1869                       7122.0                          16.03
# 1870                       7478.0                          16.83
# 1871                        304.0                           0.68
# 1872                       6633.0                          14.93
# 1873                       7067.0                          15.90
# 1874                         56.0                           0.13
#
#       Pression osmoseur (bar)  Sucre sortie osmoseur (%)  \
# 1865                    38.03                       6.03
# 1866                    43.77                      11.77
# 1867                    38.70                       6.70
# 1868                    38.11                       6.11
# 1869                    38.81                       6.81
# 1870                    44.60                      12.60
# 1871                    43.15                      11.15
# 1872                    39.45                       7.45
# 1873                    40.18                       8.18
# 1874                    41.64                       9.64
#
#       Température Bouilloire (0C)  Temps bouilloire (h)  \
# 1865                   104.273988                  6.53
# 1866                   103.669810                  1.64
# 1867                   103.808478                  6.67
# 1868                   104.001533                  9.49
# 1869                   104.253526                  8.63
# 1870                   103.881904                  5.88
# 1871                   104.012573                  1.67
# 1872                   103.810847                  6.03
# 1873                   104.641621                  8.20
# 1874                   103.819760                  1.69
#
#       Sucre du sirop obtenu (%)  Quantité de sirop obtenue (L)  \
# 1865                         68                         395.28
# 1866                         65                          17.42
# 1867                         66                         408.94
# 1868                         67                         631.51
# 1869                         68                         579.50
# 1870                         66                         521.36
# 1871                         67                          23.91
# 1872                         66                         452.75
# 1873                         70                         552.64
# 1874                         66                           4.07
#
#       Transmittance produit (%)  Classe Sirop
# 1865                      38.62         Foncé
# 1866                      39.91         Foncé
# 1867                      30.45         Foncé
# 1868                      37.09         Foncé
# 1869                      37.48         Foncé
# 1870                      46.31         Foncé
# 1871                      38.52         Foncé
# 1872                      46.69         Foncé
# 1873                      38.02         Foncé
# 1874                      33.58         Foncé
#
# [10 rows x 23 columns]

# %%
corr = dfSansPixel.corr()
corr
# Out:
#                                             Année  Jour Calendrier Saison  \
# Année                                1.000000e+00            1.002323e-14
# Jour Calendrier Saison               1.002323e-14            1.000000e+00
# Temp max.(°C)                       -1.676229e-02            7.554621e-01
# Temp min.(°C)                       -8.639671e-02            7.008612e-01
# Temp moy.(°C)                       -5.565612e-02            7.576987e-01
# Diff Temp (°C)                       1.321249e-01           -7.039623e-02
# Précip. tot. (mm)                    6.872241e-02            6.765385e-02
# Précip. Tot. Hiver (mm)              7.665733e-01           -5.084120e-04
# Nombre épisodes gel/dégel            1.377598e-01            4.647108e-03
# Production moyenne par entaille (L)  3.157464e-01            4.683584e-03
# Débit sève (L/j)                     7.522770e-02            3.638701e-01
# Sucre sève (%)                       7.326143e-02            4.330640e-01
# Alimentation osmoseur (L/j)          6.633606e-02            3.545137e-01
# Osmoseur (heures opération/j)        6.632684e-02            3.545028e-01
# Pression osmoseur (bar)              1.255842e-01            4.898962e-01
# Sucre sortie osmoseur (%)            1.026458e-01            4.330739e-01
# Température Bouilloire (0C)          1.278403e-01            4.881750e-01
# Temps bouilloire (h)                 1.035692e-01            4.453535e-01
# Sucre du sirop obtenu (%)            1.285917e-01            4.867101e-01
# Quantité de sirop obtenue (L)        6.793209e-02            3.545715e-01
# Transmittance produit (%)            1.214731e-01            2.361883e-01
#
#                                      Temp max.(°C)  Temp min.(°C)  \
# Année                                    -0.016762      -0.086397
# Jour Calendrier Saison                    0.755462       0.700861
# Temp max.(°C)                             1.000000       0.837438
# Temp min.(°C)                             0.837438       1.000000
# Temp moy.(°C)                             0.953000       0.963459
# Diff Temp (°C)                            0.072451      -0.483779
# Précip. tot. (mm)                         0.083332       0.220931
# Précip. Tot. Hiver (mm)                  -0.049811      -0.086904
# Nombre épisodes gel/dégel                 0.119972       0.114058
# Production moyenne par entaille (L)       0.113224       0.097271
# Débit sève (L/j)                          0.492896       0.238201
# Sucre sève (%)                            0.373109       0.351319
# Alimentation osmoseur (L/j)               0.480851       0.232912
# Osmoseur (heures opération/j)             0.480830       0.232900
# Pression osmoseur (bar)                   0.394669       0.407909
# Sucre sortie osmoseur (%)                 0.348952       0.365995
# Température Bouilloire (0C)               0.393400       0.404913
# Temps bouilloire (h)                      0.528002       0.318829
# Sucre du sirop obtenu (%)                 0.393066       0.404025
# Quantité de sirop obtenue (L)             0.480019       0.233508
# Transmittance produit (%)                 0.197482       0.224069
#
#                                      Temp moy.(°C)  Diff Temp (°C)  \
# Année                                    -0.055656        0.132125
# Jour Calendrier Saison                    0.757699       -0.070396
# Temp max.(°C)                             0.953000        0.072451
# Temp min.(°C)                             0.963459       -0.483779
# Temp moy.(°C)                             1.000000       -0.232314
# Diff Temp (°C)                           -0.232314        1.000000
# Précip. tot. (mm)                         0.163827       -0.269715
# Précip. Tot. Hiver (mm)                  -0.072100        0.080286
# Nombre épisodes gel/dégel                 0.122007       -0.016024
# Production moyenne par entaille (L)       0.109632        0.004554
# Débit sève (L/j)                          0.373126        0.354498
# Sucre sève (%)                            0.377236       -0.042668
# Alimentation osmoseur (L/j)               0.364306        0.344922
# Osmoseur (heures opération/j)             0.364289        0.344910
# Pression osmoseur (bar)                   0.419263       -0.111157
# Sucre sortie osmoseur (%)                 0.373708       -0.107632
# Température Bouilloire (0C)               0.416966       -0.107841
# Temps bouilloire (h)                      0.434837        0.263662
# Sucre du sirop obtenu (%)                 0.416319       -0.106752
# Quantité de sirop obtenue (L)             0.364193        0.342426
# Transmittance produit (%)                 0.221039       -0.090941
#
#                                      Précip. tot. (mm)  \
# Année                                         0.068722
# Jour Calendrier Saison                        0.067654
# Temp max.(°C)                                 0.083332
# Temp min.(°C)                                 0.220931
# Temp moy.(°C)                                 0.163827
# Diff Temp (°C)                               -0.269715
# Précip. tot. (mm)                             1.000000
# Précip. Tot. Hiver (mm)                       0.096089
# Nombre épisodes gel/dégel                    -0.002404
# Production moyenne par entaille (L)           0.015684
# Débit sève (L/j)                             -0.113511
# Sucre sève (%)                               -0.228468
# Alimentation osmoseur (L/j)                  -0.114427
# Osmoseur (heures opération/j)                -0.114424
# Pression osmoseur (bar)                       0.063510
# Sucre sortie osmoseur (%)                     0.057734
# Température Bouilloire (0C)                   0.062739
# Temps bouilloire (h)                         -0.075118
# Sucre du sirop obtenu (%)                     0.061929
# Quantité de sirop obtenue (L)                -0.152767
# Transmittance produit (%)                     0.042343
#
#                                      Précip. Tot. Hiver (mm)  \
# Année                                               0.766573
# Jour Calendrier Saison                             -0.000508
# Temp max.(°C)                                      -0.049811
# Temp min.(°C)                                      -0.086904
# Temp moy.(°C)                                      -0.072100
# Diff Temp (°C)                                      0.080286
# Précip. tot. (mm)                                   0.096089
# Précip. Tot. Hiver (mm)                             1.000000
# Nombre épisodes gel/dégel                          -0.093939
# Production moyenne par entaille (L)                 0.107329
# Débit sève (L/j)                                    0.025719
# Sucre sève (%)                                      0.054762
# Alimentation osmoseur (L/j)                         0.016826
# Osmoseur (heures opération/j)                       0.016824
# Pression osmoseur (bar)                             0.185014
# Sucre sortie osmoseur (%)                           0.146086
# Température Bouilloire (0C)                         0.189755
# Temps bouilloire (h)                                0.075229
# Sucre du sirop obtenu (%)                           0.189981
# Quantité de sirop obtenue (L)                      -0.000376
# Transmittance produit (%)                           0.159159
#
#                                      Nombre épisodes gel/dégel  \
# Année                                                 0.137760
# Jour Calendrier Saison                                0.004647
# Temp max.(°C)                                         0.119972
# Temp min.(°C)                                         0.114058
# Temp moy.(°C)                                         0.122007
# Diff Temp (°C)                                       -0.016024
# Précip. tot. (mm)                                    -0.002404
# Précip. Tot. Hiver (mm)                              -0.093939
# Nombre épisodes gel/dégel                             1.000000
# Production moyenne par entaille (L)                   0.952072
# Débit sève (L/j)                                      0.225456
# Sucre sève (%)                                        0.305440
# Alimentation osmoseur (L/j)                           0.225464
# Osmoseur (heures opération/j)                         0.225480
# Pression osmoseur (bar)                               0.069455
# Sucre sortie osmoseur (%)                             0.040155
# Température Bouilloire (0C)                           0.075696
# Temps bouilloire (h)                                  0.228858
# Sucre du sirop obtenu (%)                             0.076126
# Quantité de sirop obtenue (L)                         0.278986
# Transmittance produit (%)                             0.090065
#
#                                      Production moyenne par entaille (L)  ...  \
# Année                                                           0.315746  ...
# Jour Calendrier Saison                                          0.004684  ...
# Temp max.(°C)                                                   0.113224  ...
# Temp min.(°C)                                                   0.097271  ...
# Temp moy.(°C)                                                   0.109632  ...
# Diff Temp (°C)                                                  0.004554  ...
# Précip. tot. (mm)                                               0.015684  ...
# Précip. Tot. Hiver (mm)                                         0.107329  ...
# Nombre épisodes gel/dégel                                       0.952072  ...
# Production moyenne par entaille (L)                             1.000000  ...
# Débit sève (L/j)                                                0.237026  ...
# Sucre sève (%)                                                  0.308616  ...
# Alimentation osmoseur (L/j)                                     0.233999  ...
# Osmoseur (heures opération/j)                                   0.234013  ...
# Pression osmoseur (bar)                                         0.102139  ...
# Sucre sortie osmoseur (%)                                       0.067573  ...
# Température Bouilloire (0C)                                     0.108757  ...
# Temps bouilloire (h)                                            0.247959  ...
# Sucre du sirop obtenu (%)                                       0.109408  ...
# Quantité de sirop obtenue (L)                                   0.281866  ...
# Transmittance produit (%)                                       0.117697  ...
#
#                                      Sucre sève (%)  \
# Année                                      0.073261
# Jour Calendrier Saison                     0.433064
# Temp max.(°C)                              0.373109
# Temp min.(°C)                              0.351319
# Temp moy.(°C)                              0.377236
# Diff Temp (°C)                            -0.042668
# Précip. tot. (mm)                         -0.228468
# Précip. Tot. Hiver (mm)                    0.054762
# Nombre épisodes gel/dégel                  0.305440
# Production moyenne par entaille (L)        0.308616
# Débit sève (L/j)                           0.332086
# Sucre sève (%)                             1.000000
# Alimentation osmoseur (L/j)                0.323095
# Osmoseur (heures opération/j)              0.323080
# Pression osmoseur (bar)                    0.903895
# Sucre sortie osmoseur (%)                  0.759046
# Température Bouilloire (0C)                0.913104
# Temps bouilloire (h)                       0.534868
# Sucre du sirop obtenu (%)                  0.912599
# Quantité de sirop obtenue (L)              0.351134
# Transmittance produit (%)                  0.760474
#
#                                      Alimentation osmoseur (L/j)  \
# Année                                                   0.066336
# Jour Calendrier Saison                                  0.354514
# Temp max.(°C)                                           0.480851
# Temp min.(°C)                                           0.232912
# Temp moy.(°C)                                           0.364306
# Diff Temp (°C)                                          0.344922
# Précip. tot. (mm)                                      -0.114427
# Précip. Tot. Hiver (mm)                                 0.016826
# Nombre épisodes gel/dégel                               0.225464
# Production moyenne par entaille (L)                     0.233999
# Débit sève (L/j)                                        0.966506
# Sucre sève (%)                                          0.323095
# Alimentation osmoseur (L/j)                             1.000000
# Osmoseur (heures opération/j)                           1.000000
# Pression osmoseur (bar)                                 0.246417
# Sucre sortie osmoseur (%)                               0.205495
# Température Bouilloire (0C)                             0.249288
# Temps bouilloire (h)                                    0.887335
# Sucre du sirop obtenu (%)                               0.248696
# Quantité de sirop obtenue (L)                           0.957752
# Transmittance produit (%)                               0.225275
#
#                                      Osmoseur (heures opération/j)  \
# Année                                                     0.066327
# Jour Calendrier Saison                                    0.354503
# Temp max.(°C)                                             0.480830
# Temp min.(°C)                                             0.232900
# Temp moy.(°C)                                             0.364289
# Diff Temp (°C)                                            0.344910
# Précip. tot. (mm)                                        -0.114424
# Précip. Tot. Hiver (mm)                                   0.016824
# Nombre épisodes gel/dégel                                 0.225480
# Production moyenne par entaille (L)                       0.234013
# Débit sève (L/j)                                          0.966497
# Sucre sève (%)                                            0.323080
# Alimentation osmoseur (L/j)                               1.000000
# Osmoseur (heures opération/j)                             1.000000
# Pression osmoseur (bar)                                   0.246397
# Sucre sortie osmoseur (%)                                 0.205475
# Température Bouilloire (0C)                               0.249269
# Temps bouilloire (h)                                      0.887315
# Sucre du sirop obtenu (%)                                 0.248677
# Quantité de sirop obtenue (L)                             0.957744
# Transmittance produit (%)                                 0.225279
#
#                                      Pression osmoseur (bar)  \
# Année                                               0.125584
# Jour Calendrier Saison                              0.489896
# Temp max.(°C)                                       0.394669
# Temp min.(°C)                                       0.407909
# Temp moy.(°C)                                       0.419263
# Diff Temp (°C)                                     -0.111157
# Précip. tot. (mm)                                   0.063510
# Précip. Tot. Hiver (mm)                             0.185014
# Nombre épisodes gel/dégel                           0.069455
# Production moyenne par entaille (L)                 0.102139
# Débit sève (L/j)                                    0.257026
# Sucre sève (%)                                      0.903895
# Alimentation osmoseur (L/j)                         0.246417
# Osmoseur (heures opération/j)                       0.246397
# Pression osmoseur (bar)                             1.000000
# Sucre sortie osmoseur (%)                           0.901791
# Température Bouilloire (0C)                         0.991556
# Temps bouilloire (h)                                0.484363
# Sucre du sirop obtenu (%)                           0.990725
# Quantité de sirop obtenue (L)                       0.244653
# Transmittance produit (%)                           0.813070
#
#                                      Sucre sortie osmoseur (%)  \
# Année                                                 0.102646
# Jour Calendrier Saison                                0.433074
# Temp max.(°C)                                         0.348952
# Temp min.(°C)                                         0.365995
# Temp moy.(°C)                                         0.373708
# Diff Temp (°C)                                       -0.107632
# Précip. tot. (mm)                                     0.057734
# Précip. Tot. Hiver (mm)                               0.146086
# Nombre épisodes gel/dégel                             0.040155
# Production moyenne par entaille (L)                   0.067573
# Débit sève (L/j)                                      0.216414
# Sucre sève (%)                                        0.759046
# Alimentation osmoseur (L/j)                           0.205495
# Osmoseur (heures opération/j)                         0.205475
# Pression osmoseur (bar)                               0.901791
# Sucre sortie osmoseur (%)                             1.000000
# Température Bouilloire (0C)                           0.838176
# Temps bouilloire (h)                                  0.396529
# Sucre du sirop obtenu (%)                             0.837210
# Quantité de sirop obtenue (L)                         0.205812
# Transmittance produit (%)                             0.683051
#
#                                      Température Bouilloire (0C)  \
# Année                                                   0.127840
# Jour Calendrier Saison                                  0.488175
# Temp max.(°C)                                           0.393400
# Temp min.(°C)                                           0.404913
# Temp moy.(°C)                                           0.416966
# Diff Temp (°C)                                         -0.107841
# Précip. tot. (mm)                                       0.062739
# Précip. Tot. Hiver (mm)                                 0.189755
# Nombre épisodes gel/dégel                               0.075696
# Production moyenne par entaille (L)                     0.108757
# Débit sève (L/j)                                        0.259405
# Sucre sève (%)                                          0.913104
# Alimentation osmoseur (L/j)                             0.249288
# Osmoseur (heures opération/j)                           0.249269
# Pression osmoseur (bar)                                 0.991556
# Sucre sortie osmoseur (%)                               0.838176
# Température Bouilloire (0C)                             1.000000
# Temps bouilloire (h)                                    0.492304
# Sucre du sirop obtenu (%)                               0.999413
# Quantité de sirop obtenue (L)                           0.246921
# Transmittance produit (%)                               0.821275
#
#                                      Temps bouilloire (h)  \
# Année                                            0.103569
# Jour Calendrier Saison                           0.445354
# Temp max.(°C)                                    0.528002
# Temp min.(°C)                                    0.318829
# Temp moy.(°C)                                    0.434837
# Diff Temp (°C)                                   0.263662
# Précip. tot. (mm)                               -0.075118
# Précip. Tot. Hiver (mm)                          0.075229
# Nombre épisodes gel/dégel                        0.228858
# Production moyenne par entaille (L)              0.247959
# Débit sève (L/j)                                 0.943919
# Sucre sève (%)                                   0.534868
# Alimentation osmoseur (L/j)                      0.887335
# Osmoseur (heures opération/j)                    0.887315
# Pression osmoseur (bar)                          0.484363
# Sucre sortie osmoseur (%)                        0.396529
# Température Bouilloire (0C)                      0.492304
# Temps bouilloire (h)                             1.000000
# Sucre du sirop obtenu (%)                        0.491647
# Quantité de sirop obtenue (L)                    0.940426
# Transmittance produit (%)                        0.332516
#
#                                      Sucre du sirop obtenu (%)  \
# Année                                                 0.128592
# Jour Calendrier Saison                                0.486710
# Temp max.(°C)                                         0.393066
# Temp min.(°C)                                         0.404025
# Temp moy.(°C)                                         0.416319
# Diff Temp (°C)                                       -0.106752
# Précip. tot. (mm)                                     0.061929
# Précip. Tot. Hiver (mm)                               0.189981
# Nombre épisodes gel/dégel                             0.076126
# Production moyenne par entaille (L)                   0.109408
# Débit sève (L/j)                                      0.258837
# Sucre sève (%)                                        0.912599
# Alimentation osmoseur (L/j)                           0.248696
# Osmoseur (heures opération/j)                         0.248677
# Pression osmoseur (bar)                               0.990725
# Sucre sortie osmoseur (%)                             0.837210
# Température Bouilloire (0C)                           0.999413
# Temps bouilloire (h)                                  0.491647
# Sucre du sirop obtenu (%)                             1.000000
# Quantité de sirop obtenue (L)                         0.246013
# Transmittance produit (%)                             0.820672
#
#                                      Quantité de sirop obtenue (L)  \
# Année                                                     0.067932
# Jour Calendrier Saison                                    0.354572
# Temp max.(°C)                                             0.480019
# Temp min.(°C)                                             0.233508
# Temp moy.(°C)                                             0.364193
# Diff Temp (°C)                                            0.342426
# Précip. tot. (mm)                                        -0.152767
# Précip. Tot. Hiver (mm)                                  -0.000376
# Nombre épisodes gel/dégel                                 0.278986
# Production moyenne par entaille (L)                       0.281866
# Débit sève (L/j)                                          0.987821
# Sucre sève (%)                                            0.351134
# Alimentation osmoseur (L/j)                               0.957752
# Osmoseur (heures opération/j)                             0.957744
# Pression osmoseur (bar)                                   0.244653
# Sucre sortie osmoseur (%)                                 0.205812
# Température Bouilloire (0C)                               0.246921
# Temps bouilloire (h)                                      0.940426
# Sucre du sirop obtenu (%)                                 0.246013
# Quantité de sirop obtenue (L)                             1.000000
# Transmittance produit (%)                                 0.151547
#
#                                      Transmittance produit (%)
# Année                                                 0.121473
# Jour Calendrier Saison                                0.236188
# Temp max.(°C)                                         0.197482
# Temp min.(°C)                                         0.224069
# Temp moy.(°C)                                         0.221039
# Diff Temp (°C)                                       -0.090941
# Précip. tot. (mm)                                     0.042343
# Précip. Tot. Hiver (mm)                               0.159159
# Nombre épisodes gel/dégel                             0.090065
# Production moyenne par entaille (L)                   0.117697
# Débit sève (L/j)                                      0.157818
# Sucre sève (%)                                        0.760474
# Alimentation osmoseur (L/j)                           0.225275
# Osmoseur (heures opération/j)                         0.225279
# Pression osmoseur (bar)                               0.813070
# Sucre sortie osmoseur (%)                             0.683051
# Température Bouilloire (0C)                           0.821275
# Temps bouilloire (h)                                  0.332516
# Sucre du sirop obtenu (%)                             0.820672
# Quantité de sirop obtenue (L)                         0.151547
# Transmittance produit (%)                             1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# Correlation

# %% [markdown]
# Multiple linear regression

# %%
### liste de variables (colonnes) dépendantes
col_debit_seve = dfSansPixel['Débit sève (L/j)']
col_sucre_dans_seve = dfSansPixel['Sucre sève (%)']
col_pct_transmittance = dfSansPixel['Transmittance produit (%)']
col_productivite_seve_par_saison = dfSansPixel['Production moyenne par entaille (L)']
list_cols_dependennt_vars = [col_debit_seve, col_sucre_dans_seve, col_pct_transmittance, col_productivite_seve_par_saison]

# %%
## convertir Classe Sirop en numérique - https://www.youtube.com/watch?v=wH_ezgftiy0&t=136s
dfSansPixel['CategClasseSirop'] = dfSansPixel['Classe Sirop'].astype('category').cat.codes
dfNumerique = dfSansPixel.select_dtypes(exclude='object')
dfNumerique.dtypes
# Out:
# Année                                    int64
# Jour Calendrier Saison                   int64
# Temp max.(°C)                          float64
# Temp min.(°C)                          float64
# Temp moy.(°C)                          float64
# Diff Temp (°C)                         float64
# Précip. tot. (mm)                      float64
# Précip. Tot. Hiver (mm)                float64
# Nombre épisodes gel/dégel                int64
# Production moyenne par entaille (L)    float64
# Débit sève (L/j)                       float64
# Sucre sève (%)                         float64
# Alimentation osmoseur (L/j)            float64
# Osmoseur (heures opération/j)          float64
# Pression osmoseur (bar)                float64
# Sucre sortie osmoseur (%)              float64
# Température Bouilloire (0C)            float64
# Temps bouilloire (h)                   float64
# Sucre du sirop obtenu (%)                int64
# Quantité de sirop obtenue (L)          float64
# Transmittance produit (%)              float64
# CategClasseSirop                          int8
# dtype: object

# %% [markdown]
# Multiple Linear Regression - https://www.youtube.com/watch?v=J_LnPL3Qg70

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()

## https://www.statology.org/pandas-exclude-column/
#select all columns except 'rebounds' and 'assists'
#df.loc[:, ~df.columns.isin(['rebounds', 'assists'])]
list_reg = []
for col in list_cols_dependennt_vars:
 #   print(col.name)
    #result = reg.fit(dfNumerique[:, ~dfNumerique.columns.isin([col.name for col in list_cols_dependennt_vars])], dfNumerique[col.name])
    result = reg.fit(dfNumerique.loc[:, ~dfNumerique.columns.isin([col.name for col in list_cols_dependennt_vars])], dfNumerique[col.name])
    list_reg.append(result)


#dfNumerique['Année'].name
#list_cols_dependennt_vars[0].name
#[col.name for col in list_cols_dependennt_vars]
#reg.fit(dfNumerique.loc[:, ~dfNumerique.columns.isin([col.name for col in list_cols_dependennt_vars])], dfNumerique['Débit sève (L/j)'])
#type(dfNumerique.loc[:, ~dfNumerique.columns.isin([col.name for col in list_cols_dependennt_vars])])
#dfNumeriqueIndepVar = dfNumerique[:, ~dfNumerique.columns.isin([col.name for col in list_cols_dependennt_vars])]
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# fonction vérif distr normale

# %%
def print_dist_norm(pCol, pXlabel, pYlabel="Fonction de densité f(x)", pNbRuns=1000):
    grille_x = np.linspace(pCol.min(), pCol.max(), pNbRuns)
    dx=(pCol.max()-(pCol.min()))/(pNbRuns-1)
    mu, sigma = sts.norm.fit(pCol.values)
    param=sts.norm.fit(pCol.values)
    pdf = sts.norm.pdf(grille_x, mu, sigma)
    ax=pCol.plot.hist(density=True, bins = 10, color = 'blue', edgecolor = 'black')
    ax.set_xlabel(pXlabel)
    ax.plot(grille_x, pdf, linewidth=3, color = 'red')
    ax.set_ylabel(pYlabel)

# %%
#print_dist_norm(col_debit_seve, col_debit_seve.name)
#print_dist_norm(col_sucre_dans_seve, col_sucre_dans_seve.name)
#print_dist_norm(col_pct_transmittance, col_pct_transmittance.name)
print_dist_norm(col_productivite_seve_par_saison, col_productivite_seve_par_saison.name)

# %%
nomsvariables = pd.DataFrame(donnee.columns)
Variable=donnee["Âge"]
ax=Variable.plot.hist(density=True, bins = 10, color = 'blue', edgecolor = 'black')
ax.set_xlabel("Âge")
ax.set_ylabel("Fonction de densité f(x)")

# %% [markdown]
# "Vérifier si les données suivent une loi normale"

# %%
d=1000
grille_x = np.linspace(Variable.min(), Variable.max(), d)
dx=(Variable.max()-(Variable.min()))/(d-1)
mu, sigma = sts.norm.fit(Variable.values)
param=sts.norm.fit(Variable.values)
pdf = sts.norm.pdf(grille_x, mu, sigma)
ax=Variable.plot.hist(density=True, bins = 10, color = 'blue', edgecolor = 'black')
ax.set_xlabel("Âge")
ax.plot(grille_x, pdf, linewidth=3, color = 'red')
ax.set_ylabel("Fonction de densité f(x)")
# Out:
# Text(0, 0.5, 'Fonction de densité f(x)')

# %% [markdown]
# "Vérifier si les données suivent une loi gamma"

# %%
d=1000
grille_x = np.linspace(Variable.min(), Variable.max(), d)
dx=(Variable.max()-(Variable.min()))/(d-1)
shape,loc,scale=sts.gamma.fit(Variable.values,loc=0.1)
param=sts.gamma.fit(Variable.values)
pdf = sts.gamma.pdf(grille_x,shape,loc,scale)
ax=Variable.plot.hist(density=True, bins = 10, color = 'blue', edgecolor = 'black')
ax.set_xlabel("Âge")
ax.plot(grille_x, pdf, linewidth=3, color = 'red')
ax.set_ylabel("Fonction de densité f(x)")


sts.probplot(Variable.values, dist=sts.gamma(shape,loc,scale), plot=plt.figure().add_subplot(111))
Fit_gamma = sts.kstest(Variable.values,'gamma',param)

# %% [markdown]
# "Test d'hypothèse sur la moyenne des poids des hommes"

# %%
PoidsHommes=donnee[(donnee["Genre"] == "Homme")]["Poids (kg)"]
stats_PoidsHommes=PoidsHommes.describe()
n_H=PoidsHommes.shape[0]
X_barre_H_Poids=PoidsHommes.mean()
s_H_Poids=PoidsHommes.std()

# %%
stats_PoidsHommes
# Out:
# count    247.000000
# mean      78.144534
# std       10.512890
# min       53.900000
# 25%       70.950000
# 50%       77.300000
# 75%       85.500000
# max      116.400000
# Name: Poids (kg), dtype: float64

# %%
print(n_H)
# Out:
# 247

# %%
print(s_H_Poids)
# Out:
# 10.512889904886581

# %% [markdown]
# "Cas 1"

# %%
mhu0H=84
#sigmaHPoids=math.sqrt(100)
Z0=(X_barre_H_Poids-mhu0H)/(s_H_Poids/(math.sqrt(n_H)))
CV1 = sts.norm.isf(0.05/2)
p_value_calc1=sts.norm.sf(abs(Z0))*2
print(p_value_calc1)
# Out:
# 2.0661214948530428e-18

# %% [markdown]
# "Cas 2"

# %%
mhu0H=79
t0=(X_barre_H_Poids-mhu0H)/(s_H_Poids/(math.sqrt(n_H)))
CV2 = sts.t.isf(0.05/2,n_H-1)

p_value_calc2=sts.t.sf(abs(t0),df=(n_H-1))*2
pvalue2=sts.ttest_1samp(PoidsHommes,79)
print(X_barre_H_Poids)
print(pvalue2)
# Out:
# 78.14453441295547
# Ttest_1sampResult(statistic=-1.2788773746625888, pvalue=0.20214533914983476)

# %% [markdown]
# "Comparaison grandeurs moyennes entre hommes et femmes"
#
# "Cas 3"

# %%
GrandeursHommes=donnee[(donnee["Genre"] == "Homme")]["Grandeur (cm)"]
GrandeursFemmes=donnee[(donnee["Genre"] == "Femme")]["Grandeur (cm)"]
Stats_H=GrandeursHommes.describe()
Stats_F=GrandeursFemmes.describe()

X_barre_H_Grand=GrandeursHommes.mean()
X_barre_F_Grand=GrandeursFemmes.mean()
s_H_Grand=GrandeursHommes.std()
s_F_Grand=GrandeursFemmes.std()
n_H=GrandeursHommes.shape[0]
n_F=GrandeursFemmes.shape[0]


sigmaH=7.4
sigmaF=6.2
Z0=(X_barre_H_Grand-X_barre_F_Grand)/math.sqrt(sigmaH**2/n_H+sigmaF**2/n_F)
CV3 = sts.norm.isf(0.05/2)
p_value_calc3=sts.norm.sf(abs(Z0))*2
print(p_value_calc3)

#GrandeursHommesStats = stm.stats.DescrStatsW(GrandeursHommes)
#GrandeursFemmesStats = stm.stats.DescrStatsW(GrandeursFemmes)
    
#pval1= stm.stats.CompareMeans(GrandeursHommesStats,GrandeursFemmesStats).ztest_ind(usevar='unequal')


#SSE_H=sum(((GrandeursHommes.values-X_barre_H))**2)
#SSE_F=sum(((GrandeursFemmes.values-X_barre_F))**2)
#s_H=math.sqrt(SSE_H/(n_H-1))
#s_F=math.sqrt(SSE_F/(n_F-1))
#Sp=math.sqrt((SSE_H+SSE_F)/(n_H+n_F-2))
# Out:
# 1.5856317616633426e-99

# %% [markdown]
# "Cas 4"

# %%
Sp=math.sqrt(((n_H-1)*s_H_Grand**2+(n_F-1)*s_F_Grand**2)/(n_H+n_F-2))
t0=(X_barre_H_Grand-X_barre_F_Grand)/(Sp*math.sqrt(1/n_H+1/n_F))
CV4 = sts.t.isf(0.05/2,n_H+n_F-2)
p_value_calc4=sts.t.sf(abs(t0),df=(n_H+n_F-2))*2
pvalue4 = sts.ttest_ind(GrandeursHommes,GrandeursFemmes)

# %% [markdown]
# "Cas 5"

# %%
v=(s_H_Grand**2/n_H+s_F_Grand**2/n_F)**2/((s_H_Grand**2/n_H)**2/(n_H+1)+(s_F_Grand**2/n_F)**2/(n_F+1))-2
t0=(X_barre_H_Grand-X_barre_F_Grand)/math.sqrt(s_H_Grand**2/n_H+s_F_Grand**2/n_F)
CV5 = sts.t.isf(0.05/2,v)
p_value_calc5=sts.t.sf(abs(t0),df=(v))*2
